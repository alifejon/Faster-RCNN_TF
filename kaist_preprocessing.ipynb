# %% [markdown]
# ### KAIST Scene Text Database 전처리기:
# 1. 데이터 url:http://www.iapr-tc11.org/mediawiki/index.php/KAIST_Scene_Text_Database
# 1. 압축을 다 풀고 'kaist_dataset'아래에 이미지 데이터와 xml 파일을 두면
# 1. 각 xml 파일에서 글자하나하나 위치정보를 읽어 원본 이미지에서 글자를 별도의 이미지 파일로 저장하는 작업을 수행한다.
# 1. 결과물은 char_data 아래에 각 글자명으로 폴더를 만들고 그 아래에 원본파일명.글자명.idx.jpg로 저장
#     - char_data/{character}/{img_filename}.{character}.{idx}.jpg
#     - character가 .(dot)인 경우에는 {character}값을 dot으로 대체하여 처리

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import xml.etree.ElementTree

from os import listdir, path, makedirs
from os.path import isfile, isdir, join, basename

img_base_path = 'kaist_dataset'

def plot_img_inline(img):
    plt.figure()
    plt.imshow(np.asarray(img))
    plt.show()

char_count = dict()

def get_unique_img_name(target_path, index_name, char_name):
    idx = 0
    image_filename = '%s.jpg' %('_'.join([index_name, str(idx)]))
    full_path = join(target_path, image_filename)
    
    while path.exists(full_path):
        idx = idx + 1
        image_filename = '%s.jpg' %('_'.join([index_name, str(idx)]))
        full_path = join(target_path, image_filename)
    return full_path

def print_img(img, base_path, index_name, char_name):
    target_path = join(base_path, char_name)
    if not path.exists(target_path):
        makedirs(target_path)

    # 이미지 데이터들이 여러 폴더에 걸쳐있어서 같은 파일명과 같은 글자를 갖는 경우가 많음
    # 뒤에 idx값을 추가해 서로 다른 데이터가 다른 파일명을 갖도록 함.
    full_path = get_unique_img_name(target_path, index_name, char_name)
    img.save(full_path)
    
    if char_name not in char_count:
        char_count[char_name] = 1
    else:
        char_count[char_name] = char_count[char_name] + 1
        
    return full_path, char_name
    
def crop_character_images(base_path, index_name, output_path='char_data'):
    image_filename = index_name
    xml_filename = '.'.join([path.splitext(index_name)[0], 'xml'])
    
    # xml 파일에 확장자를 빠트린 경우가 많음. xml 파일이 없는 경우에는 xml파일명을 확장자를 제외한 것으로 설정
    if path.exists(join(base_path, xml_filename)) is False:
        xml_filename = index_name
    im = Image.open(join(base_path, image_filename))
    
#     plot_img_inline(im)
    e = xml.etree.ElementTree.parse(join(base_path, xml_filename)).getroot()

    char_result = []
    for image in e:
        for words in image:
            if words.tag == 'words':
                for word in words:
                    for char in word:
                        if len(char.attrib['char']) != 1:
                            continue
                            
                        # 글자가 .인경우 dot으로 대체
                        if char.attrib['char'] == '.':
                            char.attrib['char'] = 'dot'
                            
                        # box 영역으로 crop
                        box = (int(char.attrib['x']), int(char.attrib['y']), int(char.attrib['x']) + int(char.attrib['width']), int(char.attrib['y']) + int(char.attrib['height']))
                        region = im.crop(box)
#                         plot_img_inline(region)

                        width, height = im.size

                        # 파일로 저장
                        (full_path, char_name) = print_img(region, output_path, index_name, char.attrib['char'])
                        char_result.append({
                            'src_width': width,
                            'src_height': height,
                            'path': full_path,
                            'char': char_name,
                            'x1': int(char.attrib['x']),
                            'y1': int(char.attrib['y']),
                            'x2': int(char.attrib['x']) + int(char.attrib['width']),
                            'y2': int(char.attrib['y']) + int(char.attrib['height']),
                            'width': int(char.attrib['width']),
                            'height': int(char.attrib['height']),
                            'seg_areas': int(char.attrib['width']) * int(char.attrib['height']),
                            'origin_path': join(base_path, image_filename)
                        })
    return char_result

from os import listdir, path, makedirs
from os.path import isfile, isdir, join, basename

img_base_path = 'kaist_dataset'

fail_filenames = []

char_data_list = []
def get_recursive_dirlist(base_path):
    global char_data_list
    
    # dirname을 얻어옴
    sub_dirnames = [f for f in listdir(base_path) if isdir(join(base_path, f))]
    for dirname in sub_dirnames:
        # 각 dirname별로  recursive 호출
        next_base_path = join(base_path, dirname)
        get_recursive_dirlist(next_base_path)
        
        # 현재 dir에 jpg파일이 있는지 확인
        # KAIST데이터셋은 xxx.jpg, xxx.xml, xxx.bmp 형식으로 있기 때문에, 
        # jpg파일 목록을 가져와서 이미지 데이터 목록을 확보
        data_filenames = [f for f in listdir(next_base_path) if isfile(join(next_base_path, f)) and f.lower().endswith('.jpg')]        
        for x in data_filenames:
            try:
                char_result = crop_character_images(next_base_path, x)
                char_data_list = char_data_list + char_result
            except:
                # 데이터 형식이 잘못된 경우가 많아 exception이 발생한 경우는 그냥 버림. 대신 뭐가 문제였는지만 출력
                print('###EXCEPTION', next_base_path, x)
                fail_filenames.append((next_base_path, x))
    
get_recursive_dirlist(img_base_path)

char_data_list
# Out:
# ###EXCEPTION kaist_dataset/English/Digital_Camera/(E.S)F-others 4.jpg
# ###EXCEPTION kaist_dataset/Korean/Digital_Camera/E-night 3.jpg
# ###EXCEPTION kaist_dataset/Korean/Digital_Camera/G-others 080116-0079.jpg
# ###EXCEPTION kaist_dataset/Korean/Digital_Camera/G-others 1.JPG
# ###EXCEPTION kaist_dataset/Korean/Digital_Camera/G-others 2.jpg
# ###EXCEPTION kaist_dataset/Korean/Digital_Camera/G-others 27.JPG
# ###EXCEPTION kaist_dataset/Korean/Digital_Camera/G-others 33.JPG
# ###EXCEPTION kaist_dataset/Korean/Digital_Camera/G-others 35.JPG
# ###EXCEPTION kaist_dataset/Korean/Digital_Camera/G-others 38.JPG
# ###EXCEPTION kaist_dataset/Korean/Digital_Camera/G-others 41.JPG
# ###EXCEPTION kaist_dataset/Korean/Digital_Camera/indoor1 080119-0001.jpg
# ###EXCEPTION kaist_dataset/Korean/Digital_Camera/outdoor1 11.JPG
# ###EXCEPTION kaist_dataset/Korean/Digital_Camera/outdoor1 12.JPG
# ###EXCEPTION kaist_dataset/Korean/Digital_Camera/outdoor1 14.JPG
# ###EXCEPTION kaist_dataset/Korean/Digital_Camera/outdoor1 16.JPG
# ###EXCEPTION kaist_dataset/Korean/Digital_Camera/outdoor1 19.JPG
# ###EXCEPTION kaist_dataset/Korean/Digital_Camera/outdoor1 21.JPG
# ###EXCEPTION kaist_dataset/Korean/Digital_Camera/outdoor1 22.JPG
# ###EXCEPTION kaist_dataset/Korean/Digital_Camera/outdoor1 23.JPG
# ###EXCEPTION kaist_dataset/Korean/Digital_Camera/outdoor1 24.JPG
# ###EXCEPTION kaist_dataset/Korean/Digital_Camera/outdoor1 30.JPG
# ###EXCEPTION kaist_dataset/Korean/Digital_Camera/outdoor1 32.JPG
# ###EXCEPTION kaist_dataset/Korean/Digital_Camera/outdoor1 34.JPG
# ###EXCEPTION kaist_dataset/Korean/Digital_Camera/outdoor1 5.JPG
# ###EXCEPTION kaist_dataset/Korean/Digital_Camera/outdoor1 59.JPG
# ###EXCEPTION kaist_dataset/Korean/Digital_Camera/outdoor1 99.jpg
# ###EXCEPTION kaist_dataset/Korean/Digital_Camera/outdoor2 080119-0031.jpg
# ###EXCEPTION kaist_dataset/Korean/Digital_Camera/outdoor2 2007-12-08-day-122.jpg
# ###EXCEPTION kaist_dataset/Mixed/Digital_Camera/(C.S)C-outdoor1 063.JPG
# ###EXCEPTION kaist_dataset/Mixed/Digital_Camera/(C.S)C-outdoor1 080119-0003.jpg
# ###EXCEPTION kaist_dataset/Mixed/Digital_Camera/(C.S)C-outdoor1 10.JPG
# ###EXCEPTION kaist_dataset/Mixed/Digital_Camera/(C.S)C-outdoor1 15.JPG
# ###EXCEPTION kaist_dataset/Mixed/Digital_Camera/(C.S)C-outdoor1 17.JPG
# ###EXCEPTION kaist_dataset/Mixed/Digital_Camera/(C.S)C-outdoor1 18.JPG
# ###EXCEPTION kaist_dataset/Mixed/Digital_Camera/(C.S)C-outdoor1 20.JPG
# ###EXCEPTION kaist_dataset/Mixed/Digital_Camera/(C.S)C-outdoor1 25.JPG
# ###EXCEPTION kaist_dataset/Mixed/Digital_Camera/(C.S)C-outdoor1 26.JPG
# ###EXCEPTION kaist_dataset/Mixed/Digital_Camera/(C.S)C-outdoor1 31.JPG
# ###EXCEPTION kaist_dataset/Mixed/Digital_Camera/(C.S)C-outdoor1 42.JPG
# ###EXCEPTION kaist_dataset/Mixed/Digital_Camera/(C.S)C-outdoor1 43.JPG
# ###EXCEPTION kaist_dataset/Mixed/Digital_Camera/(C.S)C-outdoor1 44.JPG
# ###EXCEPTION kaist_dataset/Mixed/Digital_Camera/(C.S)C-outdoor1 49.JPG
# ###EXCEPTION kaist_dataset/Mixed/Digital_Camera/(C.S)C-outdoor1 9.JPG
# ###EXCEPTION kaist_dataset/Mixed/Digital_Camera/(C.S)F-others 36.JPG
# [{'char': 'T',
#   'height': 105,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02317.JPG',
#   'path': 'char_data/T/DSC02317.JPG_2.jpg',
#   'seg_areas': 6615,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 63,
#   'x1': 101,
#   'x2': 164,
#   'y1': 225,
#   'y2': 330},
#  {'char': 'R',
#   'height': 94,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02317.JPG',
#   'path': 'char_data/R/DSC02317.JPG_2.jpg',
#   'seg_areas': 5546,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 59,
#   'x1': 165,
#   'x2': 224,
#   'y1': 231,
#   'y2': 325},
#  {'char': 'E',
#   'height': 109,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02317.JPG',
#   'path': 'char_data/E/DSC02317.JPG_2.jpg',
#   'seg_areas': 6322,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 58,
#   'x1': 218,
#   'x2': 276,
#   'y1': 228,
#   'y2': 337},
#  {'char': 'N',
#   'height': 97,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02317.JPG',
#   'path': 'char_data/N/DSC02317.JPG_2.jpg',
#   'seg_areas': 6208,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 64,
#   'x1': 271,
#   'x2': 335,
#   'y1': 227,
#   'y2': 324},
#  {'char': 'D',
#   'height': 89,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02317.JPG',
#   'path': 'char_data/D/DSC02317.JPG_2.jpg',
#   'seg_areas': 7031,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 79,
#   'x1': 328,
#   'x2': 407,
#   'y1': 223,
#   'y2': 312},
#  {'char': 'I',
#   'height': 93,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02317.JPG',
#   'path': 'char_data/I/DSC02317.JPG_2.jpg',
#   'seg_areas': 3255,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 35,
#   'x1': 405,
#   'x2': 440,
#   'y1': 224,
#   'y2': 317},
#  {'char': 'C',
#   'height': 105,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02317.JPG',
#   'path': 'char_data/C/DSC02317.JPG_2.jpg',
#   'seg_areas': 7875,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 75,
#   'x1': 439,
#   'x2': 514,
#   'y1': 202,
#   'y2': 307},
#  {'char': 'A',
#   'height': 113,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02317.JPG',
#   'path': 'char_data/A/DSC02317.JPG_2.jpg',
#   'seg_areas': 9492,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 84,
#   'x1': 518,
#   'x2': 602,
#   'y1': 205,
#   'y2': 318},
#  {'char': 'M',
#   'height': 85,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02423.JPG',
#   'path': 'char_data/M/DSC02423.JPG_2.jpg',
#   'seg_areas': 6375,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 75,
#   'x1': 0,
#   'x2': 75,
#   'y1': 149,
#   'y2': 234},
#  {'char': 'O',
#   'height': 78,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02423.JPG',
#   'path': 'char_data/O/DSC02423.JPG_4.jpg',
#   'seg_areas': 6318,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 81,
#   'x1': 82,
#   'x2': 163,
#   'y1': 148,
#   'y2': 226},
#  {'char': 'N',
#   'height': 81,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02423.JPG',
#   'path': 'char_data/N/DSC02423.JPG_4.jpg',
#   'seg_areas': 5832,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 72,
#   'x1': 175,
#   'x2': 247,
#   'y1': 149,
#   'y2': 230},
#  {'char': 'O',
#   'height': 73,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02423.JPG',
#   'path': 'char_data/O/DSC02423.JPG_5.jpg',
#   'seg_areas': 6059,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 83,
#   'x1': 249,
#   'x2': 332,
#   'y1': 157,
#   'y2': 230},
#  {'char': 'K',
#   'height': 82,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02423.JPG',
#   'path': 'char_data/K/DSC02423.JPG_2.jpg',
#   'seg_areas': 5330,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 65,
#   'x1': 338,
#   'x2': 403,
#   'y1': 155,
#   'y2': 237},
#  {'char': 'R',
#   'height': 84,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02423.JPG',
#   'path': 'char_data/R/DSC02423.JPG_4.jpg',
#   'seg_areas': 5712,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 68,
#   'x1': 399,
#   'x2': 467,
#   'y1': 153,
#   'y2': 237},
#  {'char': 'A',
#   'height': 73,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02423.JPG',
#   'path': 'char_data/A/DSC02423.JPG_6.jpg',
#   'seg_areas': 4526,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 62,
#   'x1': 467,
#   'x2': 529,
#   'y1': 163,
#   'y2': 236},
#  {'char': 'F',
#   'height': 71,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02423.JPG',
#   'path': 'char_data/F/DSC02423.JPG_4.jpg',
#   'seg_areas': 2911,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 41,
#   'x1': 531,
#   'x2': 572,
#   'y1': 168,
#   'y2': 239},
#  {'char': 'T',
#   'height': 71,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02423.JPG',
#   'path': 'char_data/T/DSC02423.JPG_4.jpg',
#   'seg_areas': 3905,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 55,
#   'x1': 572,
#   'x2': 627,
#   'y1': 170,
#   'y2': 241},
#  {'char': 'H',
#   'height': 51,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02423.JPG',
#   'path': 'char_data/H/DSC02423.JPG_2.jpg',
#   'seg_areas': 2550,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 50,
#   'x1': 137,
#   'x2': 187,
#   'y1': 233,
#   'y2': 284},
#  {'char': 'A',
#   'height': 45,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02423.JPG',
#   'path': 'char_data/A/DSC02423.JPG_7.jpg',
#   'seg_areas': 1665,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 37,
#   'x1': 188,
#   'x2': 225,
#   'y1': 239,
#   'y2': 284},
#  {'char': 'N',
#   'height': 49,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02423.JPG',
#   'path': 'char_data/N/DSC02423.JPG_5.jpg',
#   'seg_areas': 2303,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 47,
#   'x1': 225,
#   'x2': 272,
#   'y1': 238,
#   'y2': 287},
#  {'char': 'D',
#   'height': 52,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02423.JPG',
#   'path': 'char_data/D/DSC02423.JPG_2.jpg',
#   'seg_areas': 2288,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 44,
#   'x1': 272,
#   'x2': 316,
#   'y1': 238,
#   'y2': 290},
#  {'char': 'I',
#   'height': 47,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02423.JPG',
#   'path': 'char_data/I/DSC02423.JPG_2.jpg',
#   'seg_areas': 846,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 18,
#   'x1': 316,
#   'x2': 334,
#   'y1': 239,
#   'y2': 286},
#  {'char': 'C',
#   'height': 46,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02423.JPG',
#   'path': 'char_data/C/DSC02423.JPG_2.jpg',
#   'seg_areas': 1656,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 36,
#   'x1': 336,
#   'x2': 372,
#   'y1': 239,
#   'y2': 285},
#  {'char': 'R',
#   'height': 47,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02423.JPG',
#   'path': 'char_data/R/DSC02423.JPG_5.jpg',
#   'seg_areas': 1598,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 34,
#   'x1': 373,
#   'x2': 407,
#   'y1': 239,
#   'y2': 286},
#  {'char': 'A',
#   'height': 40,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02423.JPG',
#   'path': 'char_data/A/DSC02423.JPG_8.jpg',
#   'seg_areas': 1520,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 38,
#   'x1': 407,
#   'x2': 445,
#   'y1': 242,
#   'y2': 282},
#  {'char': 'F',
#   'height': 43,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02423.JPG',
#   'path': 'char_data/F/DSC02423.JPG_5.jpg',
#   'seg_areas': 1075,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 25,
#   'x1': 445,
#   'x2': 470,
#   'y1': 244,
#   'y2': 287},
#  {'char': 'T',
#   'height': 44,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02423.JPG',
#   'path': 'char_data/T/DSC02423.JPG_5.jpg',
#   'seg_areas': 1936,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 44,
#   'x1': 470,
#   'x2': 514,
#   'y1': 244,
#   'y2': 288},
#  {'char': 'I',
#   'height': 107,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02629.JPG',
#   'path': 'char_data/I/DSC02629.JPG_2.jpg',
#   'seg_areas': 3745,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 35,
#   'x1': 32,
#   'x2': 67,
#   'y1': 306,
#   'y2': 413},
#  {'char': 'C',
#   'height': 109,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02629.JPG',
#   'path': 'char_data/C/DSC02629.JPG_4.jpg',
#   'seg_areas': 7630,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 70,
#   'x1': 65,
#   'x2': 135,
#   'y1': 301,
#   'y2': 410},
#  {'char': 'E',
#   'height': 118,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02629.JPG',
#   'path': 'char_data/E/DSC02629.JPG_6.jpg',
#   'seg_areas': 7906,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 67,
#   'x1': 130,
#   'x2': 197,
#   'y1': 303,
#   'y2': 421},
#  {'char': 'C',
#   'height': 103,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02629.JPG',
#   'path': 'char_data/C/DSC02629.JPG_5.jpg',
#   'seg_areas': 6901,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 67,
#   'x1': 236,
#   'x2': 303,
#   'y1': 304,
#   'y2': 407},
#  {'char': 'O',
#   'height': 101,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02629.JPG',
#   'path': 'char_data/O/DSC02629.JPG_2.jpg',
#   'seg_areas': 7070,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 70,
#   'x1': 301,
#   'x2': 371,
#   'y1': 304,
#   'y2': 405},
#  {'char': 'F',
#   'height': 90,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02629.JPG',
#   'path': 'char_data/F/DSC02629.JPG_4.jpg',
#   'seg_areas': 4770,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 53,
#   'x1': 373,
#   'x2': 426,
#   'y1': 306,
#   'y2': 396},
#  {'char': 'F',
#   'height': 93,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02629.JPG',
#   'path': 'char_data/F/DSC02629.JPG_5.jpg',
#   'seg_areas': 5115,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 55,
#   'x1': 423,
#   'x2': 478,
#   'y1': 303,
#   'y2': 396},
#  {'char': 'E',
#   'height': 93,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02629.JPG',
#   'path': 'char_data/E/DSC02629.JPG_7.jpg',
#   'seg_areas': 5208,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 56,
#   'x1': 478,
#   'x2': 534,
#   'y1': 304,
#   'y2': 397},
#  {'char': 'E',
#   'height': 88,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02629.JPG',
#   'path': 'char_data/E/DSC02629.JPG_8.jpg',
#   'seg_areas': 5368,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 61,
#   'x1': 532,
#   'x2': 593,
#   'y1': 306,
#   'y2': 394},
#  {'char': 'L',
#   'height': 95,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02633.JPG',
#   'path': 'char_data/L/DSC02633.JPG_2.jpg',
#   'seg_areas': 6175,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 65,
#   'x1': 13,
#   'x2': 78,
#   'y1': 175,
#   'y2': 270},
#  {'char': 'O',
#   'height': 97,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02633.JPG',
#   'path': 'char_data/O/DSC02633.JPG_4.jpg',
#   'seg_areas': 6111,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 63,
#   'x1': 77,
#   'x2': 140,
#   'y1': 173,
#   'y2': 270},
#  {'char': 'V',
#   'height': 104,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02633.JPG',
#   'path': 'char_data/V/DSC02633.JPG_2.jpg',
#   'seg_areas': 6448,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 62,
#   'x1': 140,
#   'x2': 202,
#   'y1': 172,
#   'y2': 276},
#  {'char': 'E',
#   'height': 97,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02633.JPG',
#   'path': 'char_data/E/DSC02633.JPG_4.jpg',
#   'seg_areas': 6208,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 64,
#   'x1': 202,
#   'x2': 266,
#   'y1': 179,
#   'y2': 276},
#  {'char': 'H',
#   'height': 97,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02633.JPG',
#   'path': 'char_data/H/DSC02633.JPG_2.jpg',
#   'seg_areas': 6596,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 68,
#   'x1': 305,
#   'x2': 373,
#   'y1': 181,
#   'y2': 278},
#  {'char': 'O',
#   'height': 96,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02633.JPG',
#   'path': 'char_data/O/DSC02633.JPG_5.jpg',
#   'seg_areas': 5760,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 60,
#   'x1': 373,
#   'x2': 433,
#   'y1': 180,
#   'y2': 276},
#  {'char': 'U',
#   'height': 92,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02633.JPG',
#   'path': 'char_data/U/DSC02633.JPG_2.jpg',
#   'seg_areas': 5888,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 64,
#   'x1': 434,
#   'x2': 498,
#   'y1': 182,
#   'y2': 274},
#  {'char': 'S',
#   'height': 95,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02633.JPG',
#   'path': 'char_data/S/DSC02633.JPG_2.jpg',
#   'seg_areas': 5985,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 63,
#   'x1': 494,
#   'x2': 557,
#   'y1': 187,
#   'y2': 282},
#  {'char': 'E',
#   'height': 94,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02633.JPG',
#   'path': 'char_data/E/DSC02633.JPG_5.jpg',
#   'seg_areas': 4982,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 53,
#   'x1': 555,
#   'x2': 608,
#   'y1': 185,
#   'y2': 279},
#  {'char': 'C',
#   'height': 78,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02857.JPG',
#   'path': 'char_data/C/DSC02857.JPG_2.jpg',
#   'seg_areas': 4056,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 52,
#   'x1': 85,
#   'x2': 137,
#   'y1': 200,
#   'y2': 278},
#  {'char': 'a',
#   'height': 67,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02857.JPG',
#   'path': 'char_data/a/DSC02857.JPG_4.jpg',
#   'seg_areas': 2747,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 41,
#   'x1': 138,
#   'x2': 179,
#   'y1': 210,
#   'y2': 277},
#  {'char': 'l',
#   'height': 79,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02857.JPG',
#   'path': 'char_data/l/DSC02857.JPG_4.jpg',
#   'seg_areas': 1975,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 25,
#   'x1': 179,
#   'x2': 204,
#   'y1': 202,
#   'y2': 281},
#  {'char': 'l',
#   'height': 84,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02857.JPG',
#   'path': 'char_data/l/DSC02857.JPG_5.jpg',
#   'seg_areas': 2436,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 29,
#   'x1': 204,
#   'x2': 233,
#   'y1': 201,
#   'y2': 285},
#  {'char': 'f',
#   'height': 85,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02857.JPG',
#   'path': 'char_data/f/DSC02857.JPG_2.jpg',
#   'seg_areas': 3315,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 39,
#   'x1': 244,
#   'x2': 283,
#   'y1': 200,
#   'y2': 285},
#  {'char': 'o',
#   'height': 66,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02857.JPG',
#   'path': 'char_data/o/DSC02857.JPG_2.jpg',
#   'seg_areas': 2970,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 45,
#   'x1': 283,
#   'x2': 328,
#   'y1': 212,
#   'y2': 278},
#  {'char': 'r',
#   'height': 70,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02857.JPG',
#   'path': 'char_data/r/DSC02857.JPG_4.jpg',
#   'seg_areas': 2940,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 42,
#   'x1': 329,
#   'x2': 371,
#   'y1': 211,
#   'y2': 281},
#  {'char': 'P',
#   'height': 80,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02857.JPG',
#   'path': 'char_data/P/DSC02857.JPG_4.jpg',
#   'seg_areas': 4640,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 58,
#   'x1': 389,
#   'x2': 447,
#   'y1': 198,
#   'y2': 278},
#  {'char': 'a',
#   'height': 69,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02857.JPG',
#   'path': 'char_data/a/DSC02857.JPG_5.jpg',
#   'seg_areas': 3105,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 45,
#   'x1': 448,
#   'x2': 493,
#   'y1': 211,
#   'y2': 280},
#  {'char': 'p',
#   'height': 69,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02857.JPG',
#   'path': 'char_data/p/DSC02857.JPG_5.jpg',
#   'seg_areas': 3105,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 45,
#   'x1': 494,
#   'x2': 539,
#   'y1': 211,
#   'y2': 280},
#  {'char': 'e',
#   'height': 68,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02857.JPG',
#   'path': 'char_data/e/DSC02857.JPG_2.jpg',
#   'seg_areas': 3128,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 46,
#   'x1': 539,
#   'x2': 585,
#   'y1': 209,
#   'y2': 277},
#  {'char': 'r',
#   'height': 66,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02857.JPG',
#   'path': 'char_data/r/DSC02857.JPG_5.jpg',
#   'seg_areas': 2706,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 41,
#   'x1': 583,
#   'x2': 624,
#   'y1': 209,
#   'y2': 275},
#  {'char': 'C',
#   'height': 95,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02858.JPG',
#   'path': 'char_data/C/DSC02858.JPG_2.jpg',
#   'seg_areas': 5795,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 61,
#   'x1': 3,
#   'x2': 64,
#   'y1': 297,
#   'y2': 392},
#  {'char': 'a',
#   'height': 77,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02858.JPG',
#   'path': 'char_data/a/DSC02858.JPG_4.jpg',
#   'seg_areas': 3773,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 49,
#   'x1': 62,
#   'x2': 111,
#   'y1': 311,
#   'y2': 388},
#  {'char': 'l',
#   'height': 84,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02858.JPG',
#   'path': 'char_data/l/DSC02858.JPG_4.jpg',
#   'seg_areas': 2604,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 31,
#   'x1': 112,
#   'x2': 143,
#   'y1': 306,
#   'y2': 390},
#  {'char': 'l',
#   'height': 88,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02858.JPG',
#   'path': 'char_data/l/DSC02858.JPG_5.jpg',
#   'seg_areas': 2904,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 33,
#   'x1': 140,
#   'x2': 173,
#   'y1': 303,
#   'y2': 391},
#  {'char': 'f',
#   'height': 97,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02858.JPG',
#   'path': 'char_data/f/DSC02858.JPG_2.jpg',
#   'seg_areas': 4074,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 42,
#   'x1': 190,
#   'x2': 232,
#   'y1': 301,
#   'y2': 398},
#  {'char': 'o',
#   'height': 74,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02858.JPG',
#   'path': 'char_data/o/DSC02858.JPG_2.jpg',
#   'seg_areas': 4144,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 56,
#   'x1': 229,
#   'x2': 285,
#   'y1': 318,
#   'y2': 392},
#  {'char': 'r',
#   'height': 77,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02858.JPG',
#   'path': 'char_data/r/DSC02858.JPG_4.jpg',
#   'seg_areas': 3234,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 42,
#   'x1': 285,
#   'x2': 327,
#   'y1': 316,
#   'y2': 393},
#  {'char': 'p',
#   'height': 94,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02858.JPG',
#   'path': 'char_data/p/DSC02858.JPG_4.jpg',
#   'seg_areas': 5734,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 61,
#   'x1': 356,
#   'x2': 417,
#   'y1': 304,
#   'y2': 398},
#  {'char': 'a',
#   'height': 77,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02858.JPG',
#   'path': 'char_data/a/DSC02858.JPG_5.jpg',
#   'seg_areas': 3773,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 49,
#   'x1': 417,
#   'x2': 466,
#   'y1': 319,
#   'y2': 396},
#  {'char': 'p',
#   'height': 80,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02858.JPG',
#   'path': 'char_data/p/DSC02858.JPG_5.jpg',
#   'seg_areas': 4320,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 54,
#   'x1': 464,
#   'x2': 518,
#   'y1': 320,
#   'y2': 400},
#  {'char': 'e',
#   'height': 81,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02858.JPG',
#   'path': 'char_data/e/DSC02858.JPG_2.jpg',
#   'seg_areas': 4131,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 51,
#   'x1': 519,
#   'x2': 570,
#   'y1': 318,
#   'y2': 399},
#  {'char': 'r',
#   'height': 85,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC02858.JPG',
#   'path': 'char_data/r/DSC02858.JPG_5.jpg',
#   'seg_areas': 3400,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 40,
#   'x1': 570,
#   'x2': 610,
#   'y1': 315,
#   'y2': 400},
#  {'char': 'c',
#   'height': 65,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03026.JPG',
#   'path': 'char_data/c/DSC03026.JPG_2.jpg',
#   'seg_areas': 4290,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 66,
#   'x1': 67,
#   'x2': 133,
#   'y1': 163,
#   'y2': 228},
#  {'char': 'a',
#   'height': 53,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03026.JPG',
#   'path': 'char_data/a/DSC03026.JPG_4.jpg',
#   'seg_areas': 2279,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 43,
#   'x1': 130,
#   'x2': 173,
#   'y1': 163,
#   'y2': 216},
#  {'char': 's',
#   'height': 51,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03026.JPG',
#   'path': 'char_data/s/DSC03026.JPG_2.jpg',
#   'seg_areas': 2397,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 47,
#   'x1': 173,
#   'x2': 220,
#   'y1': 162,
#   'y2': 213},
#  {'char': 'u',
#   'height': 51,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03026.JPG',
#   'path': 'char_data/u/DSC03026.JPG_4.jpg',
#   'seg_areas': 2652,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 52,
#   'x1': 219,
#   'x2': 271,
#   'y1': 159,
#   'y2': 210},
#  {'char': 'a',
#   'height': 47,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03026.JPG',
#   'path': 'char_data/a/DSC03026.JPG_5.jpg',
#   'seg_areas': 1927,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 41,
#   'x1': 274,
#   'x2': 315,
#   'y1': 164,
#   'y2': 211},
#  {'char': 'l',
#   'height': 56,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03026.JPG',
#   'path': 'char_data/l/DSC03026.JPG_2.jpg',
#   'seg_areas': 1960,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 35,
#   'x1': 315,
#   'x2': 350,
#   'y1': 154,
#   'y2': 210},
#  {'char': 'P',
#   'height': 90,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03026.JPG',
#   'path': 'char_data/P/DSC03026.JPG_2.jpg',
#   'seg_areas': 5670,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 63,
#   'x1': 368,
#   'x2': 431,
#   'y1': 123,
#   'y2': 213},
#  {'char': 'u',
#   'height': 61,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03026.JPG',
#   'path': 'char_data/u/DSC03026.JPG_5.jpg',
#   'seg_areas': 3599,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 59,
#   'x1': 431,
#   'x2': 490,
#   'y1': 146,
#   'y2': 207},
#  {'char': 'b',
#   'height': 82,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03026.JPG',
#   'path': 'char_data/b/DSC03026.JPG_2.jpg',
#   'seg_areas': 4920,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 60,
#   'x1': 489,
#   'x2': 549,
#   'y1': 124,
#   'y2': 206},
#  {'char': 'P',
#   'height': 63,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03075.JPG',
#   'path': 'char_data/P/DSC03075.JPG_2.jpg',
#   'seg_areas': 2961,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 47,
#   'x1': 78,
#   'x2': 125,
#   'y1': 342,
#   'y2': 405},
#  {'char': 'h',
#   'height': 58,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03075.JPG',
#   'path': 'char_data/h/DSC03075.JPG_2.jpg',
#   'seg_areas': 1450,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 25,
#   'x1': 123,
#   'x2': 148,
#   'y1': 342,
#   'y2': 400},
#  {'char': 'i',
#   'height': 62,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03075.JPG',
#   'path': 'char_data/i/DSC03075.JPG_4.jpg',
#   'seg_areas': 930,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 15,
#   'x1': 146,
#   'x2': 161,
#   'y1': 340,
#   'y2': 402},
#  {'char': 'l',
#   'height': 66,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03075.JPG',
#   'path': 'char_data/l/DSC03075.JPG_6.jpg',
#   'seg_areas': 858,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 13,
#   'x1': 161,
#   'x2': 174,
#   'y1': 340,
#   'y2': 406},
#  {'char': 'o',
#   'height': 42,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03075.JPG',
#   'path': 'char_data/o/DSC03075.JPG_4.jpg',
#   'seg_areas': 1008,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 24,
#   'x1': 175,
#   'x2': 199,
#   'y1': 357,
#   'y2': 399},
#  {'char': 'l',
#   'height': 53,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03075.JPG',
#   'path': 'char_data/l/DSC03075.JPG_7.jpg',
#   'seg_areas': 742,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 14,
#   'x1': 197,
#   'x2': 211,
#   'y1': 352,
#   'y2': 405},
#  {'char': 'o',
#   'height': 40,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03075.JPG',
#   'path': 'char_data/o/DSC03075.JPG_5.jpg',
#   'seg_areas': 1080,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 27,
#   'x1': 211,
#   'x2': 238,
#   'y1': 360,
#   'y2': 400},
#  {'char': 'g',
#   'height': 54,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03075.JPG',
#   'path': 'char_data/g/DSC03075.JPG_2.jpg',
#   'seg_areas': 1404,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 26,
#   'x1': 237,
#   'x2': 263,
#   'y1': 358,
#   'y2': 412},
#  {'char': 'y',
#   'height': 44,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03075.JPG',
#   'path': 'char_data/y/DSC03075.JPG_2.jpg',
#   'seg_areas': 1452,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 33,
#   'x1': 263,
#   'x2': 296,
#   'y1': 358,
#   'y2': 402},
#  {'char': 'L',
#   'height': 52,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03075.JPG',
#   'path': 'char_data/L/DSC03075.JPG_8.jpg',
#   'seg_areas': 1508,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 29,
#   'x1': 308,
#   'x2': 337,
#   'y1': 350,
#   'y2': 402},
#  {'char': 'i',
#   'height': 51,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03075.JPG',
#   'path': 'char_data/i/DSC03075.JPG_5.jpg',
#   'seg_areas': 663,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 13,
#   'x1': 336,
#   'x2': 349,
#   'y1': 349,
#   'y2': 400},
#  {'char': 't',
#   'height': 54,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03075.JPG',
#   'path': 'char_data/t/DSC03075.JPG_4.jpg',
#   'seg_areas': 810,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 15,
#   'x1': 350,
#   'x2': 365,
#   'y1': 347,
#   'y2': 401},
#  {'char': 'e',
#   'height': 35,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03075.JPG',
#   'path': 'char_data/e/DSC03075.JPG_4.jpg',
#   'seg_areas': 1050,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 30,
#   'x1': 363,
#   'x2': 393,
#   'y1': 362,
#   'y2': 397},
#  {'char': 'r',
#   'height': 44,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03075.JPG',
#   'path': 'char_data/r/DSC03075.JPG_4.jpg',
#   'seg_areas': 880,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 20,
#   'x1': 391,
#   'x2': 411,
#   'y1': 358,
#   'y2': 402},
#  {'char': 'a',
#   'height': 43,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03075.JPG',
#   'path': 'char_data/a/DSC03075.JPG_2.jpg',
#   'seg_areas': 989,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 23,
#   'x1': 412,
#   'x2': 435,
#   'y1': 357,
#   'y2': 400},
#  {'char': 't',
#   'height': 49,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03075.JPG',
#   'path': 'char_data/t/DSC03075.JPG_5.jpg',
#   'seg_areas': 1078,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 22,
#   'x1': 433,
#   'x2': 455,
#   'y1': 348,
#   'y2': 397},
#  {'char': 'u',
#   'height': 46,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03075.JPG',
#   'path': 'char_data/u/DSC03075.JPG_2.jpg',
#   'seg_areas': 1012,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 22,
#   'x1': 455,
#   'x2': 477,
#   'y1': 356,
#   'y2': 402},
#  {'char': 'r',
#   'height': 40,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03075.JPG',
#   'path': 'char_data/r/DSC03075.JPG_5.jpg',
#   'seg_areas': 640,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 16,
#   'x1': 478,
#   'x2': 494,
#   'y1': 356,
#   'y2': 396},
#  {'char': 'e',
#   'height': 39,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03075.JPG',
#   'path': 'char_data/e/DSC03075.JPG_5.jpg',
#   'seg_areas': 1326,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 34,
#   'x1': 494,
#   'x2': 528,
#   'y1': 356,
#   'y2': 395},
#  {'char': 'Q',
#   'height': 99,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03077.JPG',
#   'path': 'char_data/Q/DSC03077.JPG_2.jpg',
#   'seg_areas': 12870,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 130,
#   'x1': 203,
#   'x2': 333,
#   'y1': 89,
#   'y2': 188},
#  {'char': '5',
#   'height': 101,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03077.JPG',
#   'path': 'char_data/5/DSC03077.JPG_2.jpg',
#   'seg_areas': 13029,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 129,
#   'x1': 338,
#   'x2': 467,
#   'y1': 88,
#   'y2': 189},
#  {'char': 'S',
#   'height': 113,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03077.JPG',
#   'path': 'char_data/S/DSC03077.JPG_2.jpg',
#   'seg_areas': 11413,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 101,
#   'x1': 57,
#   'x2': 158,
#   'y1': 315,
#   'y2': 428},
#  {'char': 'c',
#   'height': 78,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03077.JPG',
#   'path': 'char_data/c/DSC03077.JPG_4.jpg',
#   'seg_areas': 5382,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 69,
#   'x1': 157,
#   'x2': 226,
#   'y1': 353,
#   'y2': 431},
#  {'char': 'i',
#   'height': 111,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03077.JPG',
#   'path': 'char_data/i/DSC03077.JPG_2.jpg',
#   'seg_areas': 5328,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 48,
#   'x1': 223,
#   'x2': 271,
#   'y1': 326,
#   'y2': 437},
#  {'char': 'e',
#   'height': 85,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03077.JPG',
#   'path': 'char_data/e/DSC03077.JPG_4.jpg',
#   'seg_areas': 6885,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 81,
#   'x1': 271,
#   'x2': 352,
#   'y1': 351,
#   'y2': 436},
#  {'char': 'n',
#   'height': 79,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03077.JPG',
#   'path': 'char_data/n/DSC03077.JPG_2.jpg',
#   'seg_areas': 6557,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 83,
#   'x1': 348,
#   'x2': 431,
#   'y1': 353,
#   'y2': 432},
#  {'char': 'c',
#   'height': 82,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03077.JPG',
#   'path': 'char_data/c/DSC03077.JPG_5.jpg',
#   'seg_areas': 5904,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 72,
#   'x1': 429,
#   'x2': 501,
#   'y1': 352,
#   'y2': 434},
#  {'char': 'e',
#   'height': 83,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03077.JPG',
#   'path': 'char_data/e/DSC03077.JPG_5.jpg',
#   'seg_areas': 6640,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 80,
#   'x1': 498,
#   'x2': 578,
#   'y1': 353,
#   'y2': 436},
#  {'char': 'T',
#   'height': 72,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03079.JPG',
#   'path': 'char_data/T/DSC03079.JPG_2.jpg',
#   'seg_areas': 2736,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 38,
#   'x1': 194,
#   'x2': 232,
#   'y1': 317,
#   'y2': 389},
#  {'char': 'e',
#   'height': 54,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03079.JPG',
#   'path': 'char_data/e/DSC03079.JPG_2.jpg',
#   'seg_areas': 1350,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 25,
#   'x1': 231,
#   'x2': 256,
#   'y1': 338,
#   'y2': 392},
#  {'char': 'c',
#   'height': 56,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03079.JPG',
#   'path': 'char_data/c/DSC03079.JPG_2.jpg',
#   'seg_areas': 1232,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 22,
#   'x1': 257,
#   'x2': 279,
#   'y1': 335,
#   'y2': 391},
#  {'char': 'h',
#   'height': 65,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03079.JPG',
#   'path': 'char_data/h/DSC03079.JPG_2.jpg',
#   'seg_areas': 1690,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 26,
#   'x1': 279,
#   'x2': 305,
#   'y1': 321,
#   'y2': 386},
#  {'char': 'n',
#   'height': 55,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03079.JPG',
#   'path': 'char_data/n/DSC03079.JPG_2.jpg',
#   'seg_areas': 1265,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 23,
#   'x1': 304,
#   'x2': 327,
#   'y1': 334,
#   'y2': 389},
#  {'char': 'o',
#   'height': 51,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03079.JPG',
#   'path': 'char_data/o/DSC03079.JPG_4.jpg',
#   'seg_areas': 1275,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 25,
#   'x1': 327,
#   'x2': 352,
#   'y1': 334,
#   'y2': 385},
#  {'char': 'l',
#   'height': 67,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03079.JPG',
#   'path': 'char_data/l/DSC03079.JPG_2.jpg',
#   'seg_areas': 1072,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 16,
#   'x1': 351,
#   'x2': 367,
#   'y1': 322,
#   'y2': 389},
#  {'char': 'o',
#   'height': 54,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03079.JPG',
#   'path': 'char_data/o/DSC03079.JPG_5.jpg',
#   'seg_areas': 1404,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 26,
#   'x1': 365,
#   'x2': 391,
#   'y1': 332,
#   'y2': 386},
#  {'char': 'g',
#   'height': 72,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03079.JPG',
#   'path': 'char_data/g/DSC03079.JPG_2.jpg',
#   'seg_areas': 1800,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 25,
#   'x1': 392,
#   'x2': 417,
#   'y1': 331,
#   'y2': 403},
#  {'char': 'y',
#   'height': 66,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03079.JPG',
#   'path': 'char_data/y/DSC03079.JPG_2.jpg',
#   'seg_areas': 1848,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 28,
#   'x1': 416,
#   'x2': 444,
#   'y1': 330,
#   'y2': 396},
#  {'char': 'B',
#   'height': 66,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03081.JPG',
#   'path': 'char_data/B/DSC03081.JPG_2.jpg',
#   'seg_areas': 4158,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 63,
#   'x1': 292,
#   'x2': 355,
#   'y1': 255,
#   'y2': 321},
#  {'char': 'H',
#   'height': 60,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03081.JPG',
#   'path': 'char_data/H/DSC03081.JPG_2.jpg',
#   'seg_areas': 2700,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 45,
#   'x1': 237,
#   'x2': 282,
#   'y1': 397,
#   'y2': 457},
#  {'char': 'i',
#   'height': 56,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03081.JPG',
#   'path': 'char_data/i/DSC03081.JPG_2.jpg',
#   'seg_areas': 672,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 12,
#   'x1': 282,
#   'x2': 294,
#   'y1': 400,
#   'y2': 456},
#  {'char': 's',
#   'height': 42,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03081.JPG',
#   'path': 'char_data/s/DSC03081.JPG_2.jpg',
#   'seg_areas': 882,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 21,
#   'x1': 293,
#   'x2': 314,
#   'y1': 412,
#   'y2': 454},
#  {'char': 't',
#   'height': 52,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03081.JPG',
#   'path': 'char_data/t/DSC03081.JPG_2.jpg',
#   'seg_areas': 884,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 17,
#   'x1': 314,
#   'x2': 331,
#   'y1': 405,
#   'y2': 457},
#  {'char': 'o',
#   'height': 40,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03081.JPG',
#   'path': 'char_data/o/DSC03081.JPG_2.jpg',
#   'seg_areas': 1000,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 25,
#   'x1': 329,
#   'x2': 354,
#   'y1': 415,
#   'y2': 455},
#  {'char': 'r',
#   'height': 41,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03081.JPG',
#   'path': 'char_data/r/DSC03081.JPG_2.jpg',
#   'seg_areas': 984,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 24,
#   'x1': 352,
#   'x2': 376,
#   'y1': 413,
#   'y2': 454},
#  {'char': 'y',
#   'height': 54,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03081.JPG',
#   'path': 'char_data/y/DSC03081.JPG_2.jpg',
#   'seg_areas': 1350,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 25,
#   'x1': 376,
#   'x2': 401,
#   'y1': 413,
#   'y2': 467},
#  {'char': 'D',
#   'height': 72,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03082.JPG',
#   'path': 'char_data/D/DSC03082.JPG_2.jpg',
#   'seg_areas': 5040,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 70,
#   'x1': 274,
#   'x2': 344,
#   'y1': 202,
#   'y2': 274},
#  {'char': 'G',
#   'height': 59,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03082.JPG',
#   'path': 'char_data/G/DSC03082.JPG_4.jpg',
#   'seg_areas': 2124,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 36,
#   'x1': 131,
#   'x2': 167,
#   'y1': 368,
#   'y2': 427},
#  {'char': 'e',
#   'height': 42,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03082.JPG',
#   'path': 'char_data/e/DSC03082.JPG_2.jpg',
#   'seg_areas': 756,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 18,
#   'x1': 169,
#   'x2': 187,
#   'y1': 387,
#   'y2': 429},
#  {'char': 'o',
#   'height': 36,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03082.JPG',
#   'path': 'char_data/o/DSC03082.JPG_2.jpg',
#   'seg_areas': 792,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 22,
#   'x1': 188,
#   'x2': 210,
#   'y1': 385,
#   'y2': 421},
#  {'char': 'g',
#   'height': 58,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03082.JPG',
#   'path': 'char_data/g/DSC03082.JPG_5.jpg',
#   'seg_areas': 1334,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 23,
#   'x1': 210,
#   'x2': 233,
#   'y1': 384,
#   'y2': 442},
#  {'char': 'r',
#   'height': 44,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03082.JPG',
#   'path': 'char_data/r/DSC03082.JPG_2.jpg',
#   'seg_areas': 880,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 20,
#   'x1': 233,
#   'x2': 253,
#   'y1': 382,
#   'y2': 426},
#  {'char': 'a',
#   'height': 41,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03082.JPG',
#   'path': 'char_data/a/DSC03082.JPG_4.jpg',
#   'seg_areas': 779,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 19,
#   'x1': 253,
#   'x2': 272,
#   'y1': 384,
#   'y2': 425},
#  {'char': 'p',
#   'height': 63,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03082.JPG',
#   'path': 'char_data/p/DSC03082.JPG_4.jpg',
#   'seg_areas': 1638,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 26,
#   'x1': 270,
#   'x2': 296,
#   'y1': 381,
#   'y2': 444},
#  {'char': 'h',
#   'height': 57,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03082.JPG',
#   'path': 'char_data/h/DSC03082.JPG_2.jpg',
#   'seg_areas': 1539,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 27,
#   'x1': 294,
#   'x2': 321,
#   'y1': 371,
#   'y2': 428},
#  {'char': 'y',
#   'height': 60,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03082.JPG',
#   'path': 'char_data/y/DSC03082.JPG_2.jpg',
#   'seg_areas': 1440,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 24,
#   'x1': 320,
#   'x2': 344,
#   'y1': 382,
#   'y2': 442},
#  {'char': 'M',
#   'height': 59,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03082.JPG',
#   'path': 'char_data/M/DSC03082.JPG_2.jpg',
#   'seg_areas': 2596,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 44,
#   'x1': 360,
#   'x2': 404,
#   'y1': 369,
#   'y2': 428},
#  {'char': 'a',
#   'height': 39,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03082.JPG',
#   'path': 'char_data/a/DSC03082.JPG_5.jpg',
#   'seg_areas': 858,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 22,
#   'x1': 404,
#   'x2': 426,
#   'y1': 384,
#   'y2': 423},
#  {'char': 'p',
#   'height': 58,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03082.JPG',
#   'path': 'char_data/p/DSC03082.JPG_5.jpg',
#   'seg_areas': 1450,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 25,
#   'x1': 426,
#   'x2': 451,
#   'y1': 384,
#   'y2': 442},
#  {'char': 's',
#   'height': 42,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03082.JPG',
#   'path': 'char_data/s/DSC03082.JPG_2.jpg',
#   'seg_areas': 882,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 21,
#   'x1': 451,
#   'x2': 472,
#   'y1': 382,
#   'y2': 424},
#  {'char': 'K',
#   'height': 107,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03084.JPG',
#   'path': 'char_data/K/DSC03084.JPG_2.jpg',
#   'seg_areas': 10700,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 100,
#   'x1': 264,
#   'x2': 364,
#   'y1': 141,
#   'y2': 248},
#  {'char': 'E',
#   'height': 83,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03084.JPG',
#   'path': 'char_data/E/DSC03084.JPG_6.jpg',
#   'seg_areas': 3735,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 45,
#   'x1': 55,
#   'x2': 100,
#   'y1': 342,
#   'y2': 425},
#  {'char': 'd',
#   'height': 84,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03084.JPG',
#   'path': 'char_data/d/DSC03084.JPG_4.jpg',
#   'seg_areas': 2772,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 33,
#   'x1': 92,
#   'x2': 125,
#   'y1': 341,
#   'y2': 425},
#  {'char': 'u',
#   'height': 55,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03084.JPG',
#   'path': 'char_data/u/DSC03084.JPG_2.jpg',
#   'seg_areas': 1430,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 26,
#   'x1': 117,
#   'x2': 143,
#   'y1': 370,
#   'y2': 425},
#  {'char': 'c',
#   'height': 59,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03084.JPG',
#   'path': 'char_data/c/DSC03084.JPG_4.jpg',
#   'seg_areas': 1298,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 22,
#   'x1': 143,
#   'x2': 165,
#   'y1': 369,
#   'y2': 428},
#  {'char': 'a',
#   'height': 56,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03084.JPG',
#   'path': 'char_data/a/DSC03084.JPG_4.jpg',
#   'seg_areas': 1176,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 21,
#   'x1': 165,
#   'x2': 186,
#   'y1': 372,
#   'y2': 428},
#  {'char': 't',
#   'height': 67,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03084.JPG',
#   'path': 'char_data/t/DSC03084.JPG_4.jpg',
#   'seg_areas': 1206,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 18,
#   'x1': 185,
#   'x2': 203,
#   'y1': 362,
#   'y2': 429},
#  {'char': 'i',
#   'height': 77,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03084.JPG',
#   'path': 'char_data/i/DSC03084.JPG_6.jpg',
#   'seg_areas': 924,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 12,
#   'x1': 204,
#   'x2': 216,
#   'y1': 353,
#   'y2': 430},
#  {'char': 'o',
#   'height': 53,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03084.JPG',
#   'path': 'char_data/o/DSC03084.JPG_2.jpg',
#   'seg_areas': 1166,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 22,
#   'x1': 216,
#   'x2': 238,
#   'y1': 371,
#   'y2': 424},
#  {'char': 'n',
#   'height': 53,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03084.JPG',
#   'path': 'char_data/n/DSC03084.JPG_4.jpg',
#   'seg_areas': 1696,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 32,
#   'x1': 238,
#   'x2': 270,
#   'y1': 372,
#   'y2': 425},
#  {'char': 'A',
#   'height': 79,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03084.JPG',
#   'path': 'char_data/A/DSC03084.JPG_5.jpg',
#   'seg_areas': 3081,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 39,
#   'x1': 281,
#   'x2': 320,
#   'y1': 352,
#   'y2': 431},
#  {'char': 'r',
#   'height': 59,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03084.JPG',
#   'path': 'char_data/r/DSC03084.JPG_2.jpg',
#   'seg_areas': 1298,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 22,
#   'x1': 319,
#   'x2': 341,
#   'y1': 369,
#   'y2': 428},
#  {'char': 't',
#   'height': 70,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03084.JPG',
#   'path': 'char_data/t/DSC03084.JPG_5.jpg',
#   'seg_areas': 1120,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 16,
#   'x1': 343,
#   'x2': 359,
#   'y1': 361,
#   'y2': 431},
#  {'char': 'M',
#   'height': 80,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03084.JPG',
#   'path': 'char_data/M/DSC03084.JPG_2.jpg',
#   'seg_areas': 3680,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 46,
#   'x1': 376,
#   'x2': 422,
#   'y1': 347,
#   'y2': 427},
#  {'char': 'e',
#   'height': 61,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03084.JPG',
#   'path': 'char_data/e/DSC03084.JPG_7.jpg',
#   'seg_areas': 1647,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 27,
#   'x1': 422,
#   'x2': 449,
#   'y1': 369,
#   'y2': 430},
#  {'char': 'd',
#   'height': 79,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03084.JPG',
#   'path': 'char_data/d/DSC03084.JPG_5.jpg',
#   'seg_areas': 1896,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 24,
#   'x1': 446,
#   'x2': 470,
#   'y1': 347,
#   'y2': 426},
#  {'char': 'i',
#   'height': 79,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03084.JPG',
#   'path': 'char_data/i/DSC03084.JPG_7.jpg',
#   'seg_areas': 1422,
#   'src_height': 480,
#   'src_width': 640,
#   'width': 18,
#   'x1': 470,
#   'x2': 488,
#   'y1': 350,
#   'y2': 429},
#  {'char': 'c',
#   'height': 63,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)A-shadow/DSC03084.JPG',
#   'path': 'char_data/c/DSC03084.JPG_5.jpg',
#   'seg_areas': 1260,
#   'src_height': 480,
# ...
#   'seg_areas': 5060,
#   'src_height': 600,
#   'src_width': 800,
#   'width': 55,
#   'x1': 345,
#   'x2': 400,
#   'y1': 240,
#   'y2': 332},
#  {'char': 'U',
#   'height': 93,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080116-0065.jpg',
#   'path': 'char_data/U/080116-0065.jpg_2.jpg',
#   'seg_areas': 5208,
#   'src_height': 600,
#   'src_width': 800,
#   'width': 56,
#   'x1': 399,
#   'x2': 455,
#   'y1': 244,
#   'y2': 337},
#  {'char': 'C',
#   'height': 94,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080116-0065.jpg',
#   'path': 'char_data/C/080116-0065.jpg_8.jpg',
#   'seg_areas': 5452,
#   'src_height': 600,
#   'src_width': 800,
#   'width': 58,
#   'x1': 455,
#   'x2': 513,
#   'y1': 246,
#   'y2': 340},
#  {'char': 'K',
#   'height': 94,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080116-0065.jpg',
#   'path': 'char_data/K/080116-0065.jpg_2.jpg',
#   'seg_areas': 6392,
#   'src_height': 600,
#   'src_width': 800,
#   'width': 68,
#   'x1': 513,
#   'x2': 581,
#   'y1': 250,
#   'y2': 344},
#  {'char': 'B',
#   'height': 37,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080116-0065.jpg',
#   'path': 'char_data/B/080116-0065.jpg_5.jpg',
#   'seg_areas': 888,
#   'src_height': 600,
#   'src_width': 800,
#   'width': 24,
#   'x1': 160,
#   'x2': 184,
#   'y1': 365,
#   'y2': 402},
#  {'char': '2',
#   'height': 41,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080116-0065.jpg',
#   'path': 'char_data/2/080116-0065.jpg_9.jpg',
#   'seg_areas': 943,
#   'src_height': 600,
#   'src_width': 800,
#   'width': 23,
#   'x1': 183,
#   'x2': 206,
#   'y1': 364,
#   'y2': 405},
#  {'char': 'dot',
#   'height': 22,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080116-0065.jpg',
#   'path': 'char_data/dot/080116-0065.jpg_2.jpg',
#   'seg_areas': 176,
#   'src_height': 600,
#   'src_width': 800,
#   'width': 8,
#   'x1': 205,
#   'x2': 213,
#   'y1': 388,
#   'y2': 410},
#  {'char': '3',
#   'height': 51,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080116-0065.jpg',
#   'path': 'char_data/3/080116-0065.jpg_2.jpg',
#   'seg_areas': 969,
#   'src_height': 600,
#   'src_width': 800,
#   'width': 19,
#   'x1': 215,
#   'x2': 234,
#   'y1': 363,
#   'y2': 414},
#  {'char': '1',
#   'height': 49,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080116-0065.jpg',
#   'path': 'char_data/1/080116-0065.jpg_2.jpg',
#   'seg_areas': 882,
#   'src_height': 600,
#   'src_width': 800,
#   'width': 18,
#   'x1': 236,
#   'x2': 254,
#   'y1': 369,
#   'y2': 418},
#  {'char': '4',
#   'height': 50,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080116-0065.jpg',
#   'path': 'char_data/4/080116-0065.jpg_4.jpg',
#   'seg_areas': 1150,
#   'src_height': 600,
#   'src_width': 800,
#   'width': 23,
#   'x1': 256,
#   'x2': 279,
#   'y1': 367,
#   'y2': 417},
#  {'char': '5',
#   'height': 44,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080116-0065.jpg',
#   'path': 'char_data/5/080116-0065.jpg_2.jpg',
#   'seg_areas': 1056,
#   'src_height': 600,
#   'src_width': 800,
#   'width': 24,
#   'x1': 277,
#   'x2': 301,
#   'y1': 370,
#   'y2': 414},
#  {'char': '-',
#   'height': 24,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080116-0065.jpg',
#   'path': 'char_data/-/080116-0065.jpg_2.jpg',
#   'seg_areas': 576,
#   'src_height': 600,
#   'src_width': 800,
#   'width': 24,
#   'x1': 301,
#   'x2': 325,
#   'y1': 386,
#   'y2': 410},
#  {'char': '2',
#   'height': 44,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080116-0065.jpg',
#   'path': 'char_data/2/080116-0065.jpg_10.jpg',
#   'seg_areas': 1144,
#   'src_height': 600,
#   'src_width': 800,
#   'width': 26,
#   'x1': 325,
#   'x2': 351,
#   'y1': 376,
#   'y2': 420},
#  {'char': '0',
#   'height': 41,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080116-0065.jpg',
#   'path': 'char_data/0/080116-0065.jpg_8.jpg',
#   'seg_areas': 902,
#   'src_height': 600,
#   'src_width': 800,
#   'width': 22,
#   'x1': 352,
#   'x2': 374,
#   'y1': 380,
#   'y2': 421},
#  {'char': '4',
#   'height': 42,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080116-0065.jpg',
#   'path': 'char_data/4/080116-0065.jpg_5.jpg',
#   'seg_areas': 882,
#   'src_height': 600,
#   'src_width': 800,
#   'width': 21,
#   'x1': 375,
#   'x2': 396,
#   'y1': 383,
#   'y2': 425},
#  {'char': '2',
#   'height': 47,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080116-0065.jpg',
#   'path': 'char_data/2/080116-0065.jpg_11.jpg',
#   'seg_areas': 1363,
#   'src_height': 600,
#   'src_width': 800,
#   'width': 29,
#   'x1': 397,
#   'x2': 426,
#   'y1': 383,
#   'y2': 430},
#  {'char': 'dot',
#   'height': 42,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080116-0066.jpg',
#   'path': 'char_data/dot/080116-0066.jpg_2.jpg',
#   'seg_areas': 1890,
#   'src_height': 600,
#   'src_width': 800,
#   'width': 45,
#   'x1': 337,
#   'x2': 382,
#   'y1': 300,
#   'y2': 342},
#  {'char': 'W',
#   'height': 124,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080116-0066.jpg',
#   'path': 'char_data/W/080116-0066.jpg_2.jpg',
#   'seg_areas': 21204,
#   'src_height': 600,
#   'src_width': 800,
#   'width': 171,
#   'x1': 186,
#   'x2': 357,
#   'y1': 210,
#   'y2': 334},
#  {'char': 'D',
#   'height': 45,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080116-0066.jpg',
#   'path': 'char_data/D/080116-0066.jpg_4.jpg',
#   'seg_areas': 1800,
#   'src_height': 600,
#   'src_width': 800,
#   'width': 40,
#   'x1': 277,
#   'x2': 317,
#   'y1': 351,
#   'y2': 396},
#  {'char': 'o',
#   'height': 42,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080116-0066.jpg',
#   'path': 'char_data/o/080116-0066.jpg_4.jpg',
#   'seg_areas': 1344,
#   'src_height': 600,
#   'src_width': 800,
#   'width': 32,
#   'x1': 319,
#   'x2': 351,
#   'y1': 353,
#   'y2': 395},
#  {'char': 'u',
#   'height': 45,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080116-0066.jpg',
#   'path': 'char_data/u/080116-0066.jpg_4.jpg',
#   'seg_areas': 1440,
#   'src_height': 600,
#   'src_width': 800,
#   'width': 32,
#   'x1': 352,
#   'x2': 384,
#   'y1': 352,
#   'y2': 397},
#  {'char': 'b',
#   'height': 50,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080116-0066.jpg',
#   'path': 'char_data/b/080116-0066.jpg_2.jpg',
#   'seg_areas': 2000,
#   'src_height': 600,
#   'src_width': 800,
#   'width': 40,
#   'x1': 385,
#   'x2': 425,
#   'y1': 345,
#   'y2': 395},
#  {'char': 'l',
#   'height': 54,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080116-0066.jpg',
#   'path': 'char_data/l/080116-0066.jpg_2.jpg',
#   'seg_areas': 702,
#   'src_height': 600,
#   'src_width': 800,
#   'width': 13,
#   'x1': 426,
#   'x2': 439,
#   'y1': 342,
#   'y2': 396},
#  {'char': 'e',
#   'height': 38,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080116-0066.jpg',
#   'path': 'char_data/e/080116-0066.jpg_2.jpg',
#   'seg_areas': 1368,
#   'src_height': 600,
#   'src_width': 800,
#   'width': 36,
#   'x1': 442,
#   'x2': 478,
#   'y1': 360,
#   'y2': 398},
#  {'char': 'u',
#   'height': 46,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080116-0066.jpg',
#   'path': 'char_data/u/080116-0066.jpg_5.jpg',
#   'seg_areas': 1656,
#   'src_height': 600,
#   'src_width': 800,
#   'width': 36,
#   'x1': 478,
#   'x2': 514,
#   'y1': 352,
#   'y2': 398},
#  {'char': 'D',
#   'height': 45,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080116-0066.jpg',
#   'path': 'char_data/D/080116-0066.jpg_5.jpg',
#   'seg_areas': 1620,
#   'src_height': 600,
#   'src_width': 800,
#   'width': 36,
#   'x1': 514,
#   'x2': 550,
#   'y1': 355,
#   'y2': 400},
#  {'char': 'o',
#   'height': 38,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080116-0066.jpg',
#   'path': 'char_data/o/080116-0066.jpg_5.jpg',
#   'seg_areas': 1482,
#   'src_height': 600,
#   'src_width': 800,
#   'width': 39,
#   'x1': 549,
#   'x2': 588,
#   'y1': 358,
#   'y2': 396},
#  {'char': 't',
#   'height': 50,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080116-0066.jpg',
#   'path': 'char_data/t/080116-0066.jpg_2.jpg',
#   'seg_areas': 1250,
#   'src_height': 600,
#   'src_width': 800,
#   'width': 25,
#   'x1': 588,
#   'x2': 613,
#   'y1': 350,
#   'y2': 400},
#  {'char': 'N',
#   'height': 70,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080118-0011.jpg',
#   'path': 'char_data/N/080118-0011.jpg_6.jpg',
#   'seg_areas': 3570,
#   'src_height': 1200,
#   'src_width': 1600,
#   'width': 51,
#   'x1': 375,
#   'x2': 426,
#   'y1': 943,
#   'y2': 1013},
#  {'char': 'E',
#   'height': 65,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080118-0011.jpg',
#   'path': 'char_data/E/080118-0011.jpg_10.jpg',
#   'seg_areas': 2990,
#   'src_height': 1200,
#   'src_width': 1600,
#   'width': 46,
#   'x1': 429,
#   'x2': 475,
#   'y1': 941,
#   'y2': 1006},
#  {'char': 'V',
#   'height': 65,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080118-0011.jpg',
#   'path': 'char_data/V/080118-0011.jpg_2.jpg',
#   'seg_areas': 3445,
#   'src_height': 1200,
#   'src_width': 1600,
#   'width': 53,
#   'x1': 475,
#   'x2': 528,
#   'y1': 942,
#   'y2': 1007},
#  {'char': 'E',
#   'height': 64,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080118-0011.jpg',
#   'path': 'char_data/E/080118-0011.jpg_11.jpg',
#   'seg_areas': 3008,
#   'src_height': 1200,
#   'src_width': 1600,
#   'width': 47,
#   'x1': 529,
#   'x2': 576,
#   'y1': 941,
#   'y2': 1005},
#  {'char': 'R',
#   'height': 70,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080118-0011.jpg',
#   'path': 'char_data/R/080118-0011.jpg_6.jpg',
#   'seg_areas': 4130,
#   'src_height': 1200,
#   'src_width': 1600,
#   'width': 59,
#   'x1': 576,
#   'x2': 635,
#   'y1': 938,
#   'y2': 1008},
#  {'char': 'S',
#   'height': 69,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080118-0011.jpg',
#   'path': 'char_data/S/080118-0011.jpg_2.jpg',
#   'seg_areas': 3381,
#   'src_height': 1200,
#   'src_width': 1600,
#   'width': 49,
#   'x1': 660,
#   'x2': 709,
#   'y1': 938,
#   'y2': 1007},
#  {'char': 'T',
#   'height': 66,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080118-0011.jpg',
#   'path': 'char_data/T/080118-0011.jpg_6.jpg',
#   'seg_areas': 2574,
#   'src_height': 1200,
#   'src_width': 1600,
#   'width': 39,
#   'x1': 709,
#   'x2': 748,
#   'y1': 936,
#   'y2': 1002},
#  {'char': 'O',
#   'height': 54,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080118-0011.jpg',
#   'path': 'char_data/O/080118-0011.jpg_6.jpg',
#   'seg_areas': 2808,
#   'src_height': 1200,
#   'src_width': 1600,
#   'width': 52,
#   'x1': 754,
#   'x2': 806,
#   'y1': 943,
#   'y2': 997},
#  {'char': 'P',
#   'height': 72,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080118-0011.jpg',
#   'path': 'char_data/P/080118-0011.jpg_4.jpg',
#   'seg_areas': 2952,
#   'src_height': 1200,
#   'src_width': 1600,
#   'width': 41,
#   'x1': 813,
#   'x2': 854,
#   'y1': 938,
#   'y2': 1010},
#  {'char': 'E',
#   'height': 74,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080118-0011.jpg',
#   'path': 'char_data/E/080118-0011.jpg_12.jpg',
#   'seg_areas': 3552,
#   'src_height': 1200,
#   'src_width': 1600,
#   'width': 48,
#   'x1': 879,
#   'x2': 927,
#   'y1': 932,
#   'y2': 1006},
#  {'char': 'X',
#   'height': 75,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080118-0011.jpg',
#   'path': 'char_data/X/080118-0011.jpg_2.jpg',
#   'seg_areas': 4125,
#   'src_height': 1200,
#   'src_width': 1600,
#   'width': 55,
#   'x1': 930,
#   'x2': 985,
#   'y1': 929,
#   'y2': 1004},
#  {'char': 'P',
#   'height': 72,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080118-0011.jpg',
#   'path': 'char_data/P/080118-0011.jpg_5.jpg',
#   'seg_areas': 3384,
#   'src_height': 1200,
#   'src_width': 1600,
#   'width': 47,
#   'x1': 986,
#   'x2': 1033,
#   'y1': 930,
#   'y2': 1002},
#  {'char': 'L',
#   'height': 65,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080118-0011.jpg',
#   'path': 'char_data/L/080118-0011.jpg_2.jpg',
#   'seg_areas': 3055,
#   'src_height': 1200,
#   'src_width': 1600,
#   'width': 47,
#   'x1': 1036,
#   'x2': 1083,
#   'y1': 930,
#   'y2': 995},
#  {'char': 'O',
#   'height': 66,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080118-0011.jpg',
#   'path': 'char_data/O/080118-0011.jpg_7.jpg',
#   'seg_areas': 3102,
#   'src_height': 1200,
#   'src_width': 1600,
#   'width': 47,
#   'x1': 1082,
#   'x2': 1129,
#   'y1': 930,
#   'y2': 996},
#  {'char': 'R',
#   'height': 71,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080118-0011.jpg',
#   'path': 'char_data/R/080118-0011.jpg_7.jpg',
#   'seg_areas': 3408,
#   'src_height': 1200,
#   'src_width': 1600,
#   'width': 48,
#   'x1': 1134,
#   'x2': 1182,
#   'y1': 928,
#   'y2': 999},
#  {'char': 'I',
#   'height': 69,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080118-0011.jpg',
#   'path': 'char_data/I/080118-0011.jpg_2.jpg',
#   'seg_areas': 2208,
#   'src_height': 1200,
#   'src_width': 1600,
#   'width': 32,
#   'x1': 1182,
#   'x2': 1214,
#   'y1': 925,
#   'y2': 994},
#  {'char': 'N',
#   'height': 73,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080118-0011.jpg',
#   'path': 'char_data/N/080118-0011.jpg_7.jpg',
#   'seg_areas': 3504,
#   'src_height': 1200,
#   'src_width': 1600,
#   'width': 48,
#   'x1': 1213,
#   'x2': 1261,
#   'y1': 920,
#   'y2': 993},
#  {'char': 'G',
#   'height': 66,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080118-0011.jpg',
#   'path': 'char_data/G/080118-0011.jpg_2.jpg',
#   'seg_areas': 3102,
#   'src_height': 1200,
#   'src_width': 1600,
#   'width': 47,
#   'x1': 1262,
#   'x2': 1309,
#   'y1': 920,
#   'y2': 986},
#  {'char': 'T',
#   'height': 72,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080118-0011.jpg',
#   'path': 'char_data/T/080118-0011.jpg_7.jpg',
#   'seg_areas': 4320,
#   'src_height': 1200,
#   'src_width': 1600,
#   'width': 60,
#   'x1': 746,
#   'x2': 806,
#   'y1': 458,
#   'y2': 530},
#  {'char': 'H',
#   'height': 73,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080118-0011.jpg',
#   'path': 'char_data/H/080118-0011.jpg_4.jpg',
#   'seg_areas': 4015,
#   'src_height': 1200,
#   'src_width': 1600,
#   'width': 55,
#   'x1': 805,
#   'x2': 860,
#   'y1': 457,
#   'y2': 530},
#  {'char': 'E',
#   'height': 70,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080118-0011.jpg',
#   'path': 'char_data/E/080118-0011.jpg_13.jpg',
#   'seg_areas': 3570,
#   'src_height': 1200,
#   'src_width': 1600,
#   'width': 51,
#   'x1': 860,
#   'x2': 911,
#   'y1': 457,
#   'y2': 527},
#  {'char': 'N',
#   'height': 73,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080118-0011.jpg',
#   'path': 'char_data/N/080118-0011.jpg_8.jpg',
#   'seg_areas': 4161,
#   'src_height': 1200,
#   'src_width': 1600,
#   'width': 57,
#   'x1': 631,
#   'x2': 688,
#   'y1': 526,
#   'y2': 599},
#  {'char': 'O',
#   'height': 71,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080118-0011.jpg',
#   'path': 'char_data/O/080118-0011.jpg_8.jpg',
#   'seg_areas': 4402,
#   'src_height': 1200,
#   'src_width': 1600,
#   'width': 62,
#   'x1': 689,
#   'x2': 751,
#   'y1': 526,
#   'y2': 597},
#  {'char': 'R',
#   'height': 64,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080118-0011.jpg',
#   'path': 'char_data/R/080118-0011.jpg_8.jpg',
#   'seg_areas': 3520,
#   'src_height': 1200,
#   'src_width': 1600,
#   'width': 55,
#   'x1': 752,
#   'x2': 807,
#   'y1': 531,
#   'y2': 595},
#  {'char': 'T',
#   'height': 65,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080118-0011.jpg',
#   'path': 'char_data/T/080118-0011.jpg_8.jpg',
#   'seg_areas': 3445,
#   'src_height': 1200,
#   'src_width': 1600,
#   'width': 53,
#   'x1': 805,
#   'x2': 858,
#   'y1': 529,
#   'y2': 594},
#  {'char': 'H',
#   'height': 69,
#   'origin_path': 'kaist_dataset/English/Digital_Camera/(E.S)C-outdoor1/080118-0011.jpg',
#   'path': 'char_data/H/080118-0011.jpg_5.jpg',
#   'seg_areas': 3864,
#   'src_height': 1200,
#   'src_width': 1600,
#   'width': 56,
#   'x1': 858,
#   'x2': 914,
#   'y1': 527,
#   'y2': 596},
#  ...]

# %%
import pandas as pd

dataDF = pd.DataFrame(char_data_list)
dataDF['isTrain'] = True

charCount = dataDF['char'].value_counts()
targetChars = charCount.loc[charCount > 100]

datasetDFList = []
for char in targetChars.index:
    charDF = dataDF.loc[dataDF['char'] == char]
    
    train_idx = int(len(charDF) * 0.8)
    
    datasetDFList.append(charDF)
    charDF.iloc[:train_idx].loc[:, 'isTrain'] = True
    charDF.iloc[train_idx:].loc[:, 'isTrain'] = False
    
#     trainCharDF = charDF[:train_idx]
#     testCharDF = charDF[train_idx:]
#     trainCharDF['isTrain'] = True
#     testCharDF['isTrain'] = False
#     datasetDFList.append(trainCharDF)
#     datasetDFList.append(testCharDF)
    
#     print(char, len(charDF), len(charDF[:train_idx]), len(charDF[train_idx:]))

datasetDF = pd.concat(datasetDFList)
datasetDF

charList = sorted(datasetDF['char'].unique())

datasetDF['label'] = datasetDF['char'].apply(lambda char: charList.index(char) + 1)

datasetDF.loc[(datasetDF['x1'] == 0), 'x1'] = 1
datasetDF.loc[(datasetDF['y1'] == 0), 'y1'] = 1
datasetDF.loc[(datasetDF['x2'] >= datasetDF['src_width']), 'x2'] = datasetDF.loc[(datasetDF['x2'] >= datasetDF['src_width']), 'src_width'] - 1
datasetDF.loc[(datasetDF['y2'] >= datasetDF['src_height']), 'y2'] = datasetDF.loc[(datasetDF['y2'] >= datasetDF['src_height']), 'src_height'] - 1

datasetDF = datasetDF.loc[(datasetDF['x1'] < datasetDF['x2']) & (datasetDF['y1'] < datasetDF['y2'])]

datasetDF.to_csv('kaist_rcnn.csv', index=False)

trainTestDFList = []

for char in targetChars.index:
    charSampleDF = pd.concat([
        datasetDF.loc[(datasetDF['char'] == char) & (datasetDF['isTrain'] == True)].sample(n=800, replace=True),
        datasetDF.loc[(datasetDF['char'] == char) & (datasetDF['isTrain'] == False)].sample(n=200, replace=True)
    ])
    trainTestDFList.append(charSampleDF)
    
trainTestDF = pd.concat(trainTestDFList)

# shuffle data rows
trainTestDF = trainTestDF.sample(frac=1).reset_index(drop=True)

trainTestDF.to_csv('kaist_dataset.csv')
trainTestDF.loc[trainTestDF['isTrain'] == True].to_csv('kaist_dataset_train.csv', header=False, index=False)
trainTestDF.loc[trainTestDF['isTrain'] == False].to_csv('kaist_dataset_test.csv', header=False, index=False)

trainTestDF
# Out:
# /Users/ali.jeon/.pyenv/versions/3.6.2/envs/test_tf/lib/python3.6/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#       char  height                                        origin_path  \
# 0        y      82  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 1        O      42  kaist_dataset/English/Digital_Camera/(E.S)F-ot...
# 2        라      39  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 3        -      18  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 4        T      40  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 5        부      32  kaist_dataset/English/Digital_Camera/(E.S)B-li...
# 6        D     100  kaist_dataset/Mixed/Digital_Camera/(C.S)A-shad...
# 7        d      49  kaist_dataset/English/Digital_Camera/(E.S)D-in...
# 8        전      30  kaist_dataset/Korean/Digital_Camera/outdoor1/3...
# 9        N      24  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 10       s      44  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 11       e      25  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 12       a      60  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 13       O     192  kaist_dataset/English/Digital_Camera/(E.S)F-ot...
# 14       i      42  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 15       G      59  kaist_dataset/English/Digital_Camera/(E.S)D-in...
# 16       I      24  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 17       n      35  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 18       n      77  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 19       5      33  kaist_dataset/Korean/Digital_Camera/outdoor7/P...
# 20       하     154  kaist_dataset/Korean/Digital_Camera/outdoor1/2...
# 21       n      57  kaist_dataset/English/Digital_Camera/(E.S)D-in...
# 22       a      35  kaist_dataset/Mixed/Digital_Camera/(C.S)D-indo...
# 23       사      62  kaist_dataset/Mixed/Mobile_Phone/(C.M)B-indoor...
# 24       화     148  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 25       지      43  kaist_dataset/Korean/Mobile_Phone/(M,K)E-bookC...
# 26       아     119  kaist_dataset/Korean/Digital_Camera/indoor1/DS...
# 27       지     121  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 28       s      58  kaist_dataset/English/Digital_Camera/(E.S)D-in...
# 29       O      54  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# ...    ...     ...                                                ...
# 86970    하      52  kaist_dataset/Korean/Digital_Camera/outdoor7/P...
# 86971    m      78  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 86972    트      50  kaist_dataset/Korean/Digital_Camera/indoor2/DS...
# 86973    0      36  kaist_dataset/Mixed/Digital_Camera/(C.S)D-indo...
# 86974    r      74  kaist_dataset/English/Mobile_Phone/(E.M)B-indo...
# 86975    리      81  kaist_dataset/Korean/Mobile_Phone/(M,K)A-shado...
# 86976    비      62  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 86977    0      34  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 86978    서      70  kaist_dataset/Korean/Digital_Camera/outdoor1/2...
# 86979    서      86  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 86980    g      71  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 86981    I      24  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 86982    구     114  kaist_dataset/Korean/Digital_Camera/outdoor7/P...
# 86983    e      68  kaist_dataset/English/Digital_Camera/(E.S)A-sh...
# 86984    의     182  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 86985    도     112  kaist_dataset/Korean/Digital_Camera/outdoor3/D...
# 86986    학     235  kaist_dataset/Korean/Digital_Camera/F-bookCove...
# 86987    6      50  kaist_dataset/Korean/Digital_Camera/outdoor2/2...
# 86988    P     116  kaist_dataset/English/Digital_Camera/(E.S)B-li...
# 86989    K     111  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 86990    소     127  kaist_dataset/Korean/Mobile_Phone/(M,K)E-bookC...
# 86991    만      48  kaist_dataset/Korean/Digital_Camera/outdoor4/D...
# 86992    국      85  kaist_dataset/Korean/Mobile_Phone/(M,K)E-bookC...
# 86993    전      56  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 86994    c      24  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 86995    학      74  kaist_dataset/Korean/Digital_Camera/outdoor6/D...
# 86996    학     237  kaist_dataset/Korean/Mobile_Phone/(M,K)E-bookC...
# 86997    자      92  kaist_dataset/Korean/Mobile_Phone/(M,K)E-bookC...
# 86998    G     112  kaist_dataset/English/Digital_Camera/(E.S)E-ni...
# 86999    9      34  kaist_dataset/Korean/Digital_Camera/outdoor5/D...
#
#                                                     path  seg_areas  \
# 0                        char_data/y/DSC04437.JPG_11.jpg       4100
# 1      char_data/O/2007-12-09-day-exterior-047.jpg_10...       1134
# 2                         char_data/라/DSC02350.JPG_2.jpg       1521
# 3                              char_data/-/081.JPG_2.jpg        324
# 4                         char_data/T/DSC02938.JPG_2.jpg       1240
# 5                      char_data/부/080116-0059.jpg_7.jpg        608
# 6                        char_data/D/DSC02609.JPG_12.jpg       7800
# 7                     char_data/d/080119-0009.jpg_13.jpg        980
# 8                               char_data/전/39.jpg_2.jpg        750
# 9                        char_data/N/DSC02500.JPG_12.jpg        480
# 10                        char_data/s/DSC04035.JPG_2.jpg       1188
# 11                              char_data/e/47.JPG_2.jpg        600
# 12                        char_data/a/DSC03635.JPG_2.jpg       3000
# 13     char_data/O/2007-12-09-day-exterior-047.jpg_8.jpg      28608
# 14                        char_data/i/DSC03586.JPG_2.jpg        420
# 15                        char_data/G/DSC03345.JPG_2.jpg       3068
# 16                       char_data/I/DSC02500.JPG_10.jpg        192
# 17                        char_data/n/DSC03821.JPG_5.jpg        700
# 18                        char_data/n/DSC03630.JPG_2.jpg       3696
# 19                       char_data/5/P1010091.JPG_10.jpg        660
# 20              char_data/하/2007-12-08-day-050.jpg_4.jpg      14014
# 21                        char_data/n/DSC03074.JPG_8.jpg       1140
# 22                        char_data/a/DSC03096.JPG_8.jpg        560
# 23                      char_data/사/P090831014.jpg_2.jpg       4340
# 24                        char_data/화/DSC03675.JPG_2.jpg      12136
# 25                      char_data/지/P090831034.jpg_4.jpg       1376
# 26                        char_data/아/DSC03351.JPG_2.jpg      12376
# 27                        char_data/지/DSC02551.JPG_2.jpg      13673
# 28                        char_data/s/DSC03441.JPG_2.jpg       2378
# 29                       char_data/O/DSC04079.JPG_15.jpg       2376
# ...                                                  ...        ...
# 86970                     char_data/하/P1010077.JPG_2.jpg       2548
# 86971                     char_data/m/DSC02493.JPG_5.jpg       7488
# 86972                     char_data/트/DSC03474.JPG_2.jpg       2400
# 86973                     char_data/0/DSC02746.JPG_7.jpg        864
# 86974                   char_data/r/P090911083.jpg_2.jpg       2294
# 86975                   char_data/리/P090912067.jpg_2.jpg       7614
# 86976  char_data/비/2007-12-09-day-exterior-078.jpg_5.jpg       2232
# 86977                     char_data/0/DSC03162.JPG_4.jpg        612
# 86978           char_data/서/2007-12-08-day-050.jpg_2.jpg       3850
# 86979                     char_data/서/DSC04056.JPG_2.jpg       4816
# 86980                     char_data/g/DSC04052.JPG_5.jpg       2556
# 86981                     char_data/I/DSC03250.JPG_2.jpg        288
# 86982                     char_data/구/P1010056.JPG_4.jpg       4902
# 86983                     char_data/e/DSC02857.JPG_2.jpg       3128
# 86984                  char_data/의/080118-0007.jpg_2.jpg      24388
# 86985                     char_data/도/DSC03231.JPG_2.jpg      13328
# 86986                     char_data/학/DSC02823.JPG_2.jpg      38070
# 86987  char_data/6/2007-12-09-day-exterior-035.jpg_9.jpg       1600
# 86988                  char_data/P/080116-0053.jpg_2.jpg       9396
# 86989                     char_data/K/DSC03823.JPG_2.jpg       9102
# 86990                   char_data/소/P090903060.jpg_2.jpg      20066
# 86991                     char_data/만/DSC03589.JPG_2.jpg       1536
# 86992                   char_data/국/P090831144.jpg_2.jpg       4675
# 86993                     char_data/전/DSC02483.JPG_2.jpg       3360
# 86994                     char_data/c/P1010069.JPG_4.jpg        408
# 86995                     char_data/학/DSC04292.JPG_2.jpg       4440
# 86996                   char_data/학/P090911006.jpg_2.jpg      51192
# 86997                   char_data/자/P090903049.jpg_2.jpg       8740
# 86998                  char_data/G/080116-0056.jpg_2.jpg      11984
# 86999                    char_data/9/DSC03671.JPG_10.jpg        544
#
#        src_height  src_width  width    x1    x2    y1    y2  isTrain  label
# 0             480        640     50   258   308   118   200     True     47
# 1            1200       1600     27   663   690  1070  1112     True     25
# 2             480        640     39   520   559   351   390     True     58
# 3             480        640     18   274   292   265   283     True      1
# 4             480        640     31   381   412   240   280     True     29
# 5            1200       1600     19   565   584   996  1028     True     62
# 6             480        640     78   275   353   191   291     True     15
# 7            1200       1600     20   657   677  1028  1077     True     33
# 8             197        320     25   186   211    39    69     True     79
# 9             480        640     20     1    20    82   106     True     24
# 10            480        640     27   430   457   200   244     True     43
# 11            576        768     24   389   413   187   212     True     34
# 12            480        640     50   422   472   171   231     True     31
# 13           1200       1600    149   790   939   456   648     True     25
# 14            480        640     10   468   478   158   200     True     37
# 15            480        640     52   328   380    89   148     True     18
# 16            480        640      8    81    89    84   108     True     20
# 17            480        640     20   431   451    45    80     True     40
# 18            480        640     48   367   415   351   428     True     40
# 19            480        640     20   376   396   234   267     True      7
# 20           1200       1600     91   833   924   292   446     True     84
# 21            480        640     20   475   495   261   318     True     40
# 22            480        640     16   384   400   425   460    False     31
# 23            480        640     70   325   395    98   160    False     64
# 24            480        640     82   377   459   181   329     True     87
# 25            480        640     32   327   359   341   384     True     82
# 26            480        640    104   194   298   147   266     True     71
# 27            480        640    113   151   264   107   228     True     82
# 28            480        640     41   330   371   387   445     True     43
# 29            480        640     44   346   390    46   100     True     25
# ...           ...        ...    ...   ...   ...   ...   ...      ...    ...
# 86970         480        640     49   340   389   308   360     True     84
# 86971         480        640     96   164   260   294   372     True     39
# 86972         480        640     48   292   340   209   259     True     83
# 86973         480        640     24   123   147   296   332    False      2
# 86974         480        640     31   504   535   221   295     True     42
# 86975         480        640     94   232   326   186   267     True     59
# 86976        1200       1600     36  1104  1140   421   483     True     63
# 86977         480        640     18   502   520   146   180     True      2
# 86978        1200       1600     55   639   694   926   996     True     65
# 86979         480        640     56   240   296   325   411     True     65
# 86980         480        640     36   412   448   155   226     True     35
# 86981         480        640     12   563   575   378   402     True     20
# 86982         480        640     43   448   491   130   244     True     51
# 86983         480        640     46   539   585   209   277     True     34
# 86984        1200       1600    134   973  1107   196   378     True     74
# 86985         480        640    119   214   333   172   284     True     56
# 86986         480        640    162   381   543   149   384     True     85
# 86987        1200       1600     32   776   808   717   767     True      8
# 86988         600        800     81   422   503   217   333     True     26
# 86989         480        640     82   319   401    75   186    False     21
# 86990         480        640    158   260   418   202   329     True     67
# 86991         480        640     32   209   241   192   240     True     60
# 86992         480        640     55   295   350    26   111     True     52
# 86993         480        640     60   213   273   287   343     True     79
# 86994         480        640     17   234   251   302   326    False     32
# 86995         480        640     60   394   454    18    92     True     85
# 86996         480        640    216   342   558   121   358     True     85
# 86997         480        640     95   425   520   252   344     True     77
# 86998        1200       1600    107   620   727   556   668     True     18
# 86999         480        640     16   307   323   412   446     True     11
#
# [87000 rows x 14 columns]

# %%
datasetDF.apply(lambda x: x['x1'] > 0 and x['x2'] < x['src_width'] and x['y1'] > 0 and x['y2'] < x['src_height'] and x['x1'] < x['x2'] and x['y1'] < x['y2'] , axis=1).unique()
# Out:
# array([ True, False], dtype=bool)

# %%
datasetDF.loc[(datasetDF['x1'] > 0) & (datasetDF['x2'] < datasetDF['src_width']) & (datasetDF['y1'] > 0) & (datasetDF['y2'] < datasetDF['src_height']) & (datasetDF['x1'] < datasetDF['x2']) & (datasetDF['y1'] < datasetDF['y2'])]
# Out:
#       char  height                                        origin_path  \
# 766      8      24  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 812      8      27  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 902      8      32  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 1455     8      37  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 1460     8      36  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 1463     8      34  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 1554     8      44  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 1648     8      42  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 1651     8      43  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 1653     8      41  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 1680     8      82  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 1986     8      44  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 1992     8      42  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 2033     8      54  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 2035     8      50  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 2051     8      32  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 2127     8      58  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 2447     8      33  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 2842     8      65  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 3131     8      50  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 3132     8      49  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 3267     8      22  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 3268     8      23  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 3269     8      24  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 4337     8      59  kaist_dataset/English/Digital_Camera/(E.S)E-ni...
# 4342     8      52  kaist_dataset/English/Digital_Camera/(E.S)E-ni...
# 4663     8      30  kaist_dataset/English/Digital_Camera/(E.S)F-ot...
# 4665     8      31  kaist_dataset/English/Digital_Camera/(E.S)F-ot...
# 4707     8      42  kaist_dataset/English/Digital_Camera/(E.S)F-ot...
# 5280     8      48  kaist_dataset/Korean/Digital_Camera/A-shadow/2...
# ...    ...     ...                                                ...
# 21515    만     158  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 23030    만      48  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 23334    만      38  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 23429    만      65  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 23556    만      67  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 24360    만      81  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 25169    만      48  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 25355    만      72  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 25423    만     107  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 25662    만      47  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 25753    만     135  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 25820    만      57  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 26050    만      28  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 26084    만      93  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 26115    만      30  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 26589    만     108  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 26676    만     103  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 27284    만      76  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 27315    만      37  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 27353    만     115  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 27640    만      73  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 27994    만      46  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 28028    만     107  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 28043    만      46  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 28513    만      74  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 30364    만      67  kaist_dataset/Mixed/Digital_Camera/(C.S)D-indo...
# 31216    만      66  kaist_dataset/Mixed/Digital_Camera/(C.S)D-indo...
# 33391    만     142  kaist_dataset/Mixed/Mobile_Phone/(C.M)C-bookCo...
# 33424    만      71  kaist_dataset/Mixed/Mobile_Phone/(C.M)C-bookCo...
# 33437    만     222  kaist_dataset/Mixed/Mobile_Phone/(C.M)C-bookCo...
#
#                                                     path  seg_areas  \
# 766                            char_data/8/042.JPG_1.jpg        456
# 812                            char_data/8/056.JPG_1.jpg        432
# 902                            char_data/8/077.JPG_1.jpg        544
# 1455                      char_data/8/DSC02364.JPG_3.jpg        518
# 1460                      char_data/8/DSC02364.JPG_4.jpg        756
# 1463                      char_data/8/DSC02364.JPG_5.jpg        544
# 1554                      char_data/8/DSC02415.JPG_1.jpg       1144
# 1648                      char_data/8/DSC02450.JPG_3.jpg       1386
# 1651                      char_data/8/DSC02450.JPG_4.jpg       1462
# 1653                      char_data/8/DSC02450.JPG_5.jpg       1189
# 1680                      char_data/8/DSC02491.JPG_1.jpg       3772
# 1986                      char_data/8/DSC03053.JPG_2.jpg       1188
# 1992                      char_data/8/DSC03053.JPG_3.jpg       1176
# 2033                      char_data/8/DSC03161.JPG_2.jpg       1674
# 2035                      char_data/8/DSC03161.JPG_3.jpg       1650
# 2051                      char_data/8/DSC03162.JPG_1.jpg        448
# 2127                      char_data/8/DSC03201.JPG_1.jpg       2146
# 2447                      char_data/8/DSC03436.JPG_1.jpg        825
# 2842                      char_data/8/DSC04163.JPG_1.jpg       2535
# 3131                      char_data/8/P1010086.JPG_3.jpg       1550
# 3132                      char_data/8/P1010086.JPG_4.jpg       1323
# 3267           char_data/8/크기변환_P1010076.JPG_3.jpg        242
# 3268           char_data/8/크기변환_P1010076.JPG_4.jpg        207
# 3269           char_data/8/크기변환_P1010076.JPG_5.jpg        360
# 4337                      char_data/8/DSC02610.JPG_2.jpg       2006
# 4342                      char_data/8/DSC02610.JPG_3.jpg       2132
# 4663                      char_data/8/DSC02923.JPG_2.jpg        360
# 4665                      char_data/8/DSC02923.JPG_3.jpg        589
# 4707                             char_data/8/m.jpg_1.jpg        672
# 5280   char_data/8/2007-12-09-day-exterior-025.jpg_2.jpg       1776
# ...                                                  ...        ...
# 21515                     char_data/만/DSC02359.JPG_1.jpg      16748
# 23030                     char_data/만/DSC02912.JPG_1.jpg       1728
# 23334                     char_data/만/P1010013.JPG_1.jpg       1444
# 23429                     char_data/만/DSC02964.JPG_1.jpg       3185
# 23556                     char_data/만/DSC02989.JPG_1.jpg       2144
# 24360                     char_data/만/DSC03273.JPG_1.jpg       5103
# 25169                     char_data/만/DSC03556.JPG_1.jpg       1680
# 25355                     char_data/만/DSC03586.JPG_1.jpg       3816
# 25423                     char_data/만/DSC03616.JPG_1.jpg       9951
# 25662                     char_data/만/DSC03642.JPG_1.jpg       1457
# 25753                     char_data/만/DSC03655.JPG_1.jpg      13905
# 25820                     char_data/만/DSC03660.JPG_1.jpg       3705
# 26050                     char_data/만/DSC03674.JPG_1.jpg        588
# 26084                     char_data/만/DSC03676.JPG_1.jpg       5115
# 26115                     char_data/만/DSC03677.JPG_1.jpg        540
# 26589                     char_data/만/DSC03734.JPG_1.jpg      10260
# 26676                     char_data/만/DSC03743.JPG_1.jpg      11536
# 27284                     char_data/만/DSC04017.JPG_1.jpg       4256
# 27315                     char_data/만/DSC04029.JPG_1.jpg       1554
# 27353                     char_data/만/DSC04032.JPG_1.jpg      13685
# 27640                     char_data/만/DSC04071.JPG_1.jpg       4526
# 27994                     char_data/만/DSC04125.JPG_1.jpg       1794
# 28028                     char_data/만/DSC04135.JPG_2.jpg       3959
# 28043                     char_data/만/DSC04135.JPG_3.jpg       2760
# 28513                     char_data/만/DSC04357.JPG_1.jpg       5106
# 30364                     char_data/만/DSC02782.JPG_1.jpg       5695
# 31216                     char_data/만/DSC03998.JPG_1.jpg       4158
# 33391                   char_data/만/P090903022.jpg_1.jpg      19312
# 33424                   char_data/만/P090903024.jpg_1.jpg       5396
# 33437                   char_data/만/P090903063.jpg_1.jpg      23088
#
#        src_height  src_width  width   x1   x2   y1   y2  isTrain  label
# 766           480        640     19  485  504  321  345     True     10
# 812           480        640     16  513  529  249  276     True     10
# 902           480        640     17  276  293  248  280     True     10
# 1455          480        640     14  325  339  350  387     True     10
# 1460          480        640     21  486  507  353  389     True     10
# 1463          480        640     16  549  565  353  387     True     10
# 1554          480        640     26  393  419  250  294     True     10
# 1648          480        640     33  109  142  222  264     True     10
# 1651          480        640     34  265  299  222  265     True     10
# 1653          480        640     29  353  382  221  262     True     10
# 1680          480        640     46  238  284  315  397     True     10
# 1986          480        640     27  335  362  128  172     True     10
# 1992          480        640     28  513  541  128  170     True     10
# 2033          480        640     31  138  169  221  275     True     10
# 2035          480        640     33  200  233  223  273     True     10
# 2051          480        640     14  425  439  149  181     True     10
# 2127          480        640     37  364  401   11   69     True     10
# 2447          480        640     25  221  246  126  159     True     10
# 2842          480        640     39  194  233  316  381     True     10
# 3131          480        640     31  423  454   96  146     True     10
# 3132          480        640     27  453  480   96  145     True     10
# 3267          480        640     11  581  592  181  203     True     10
# 3268          480        640      9  595  604  182  205     True     10
# 3269          480        640     15  611  626  179  203     True     10
# 4337          480        640     34   50   84  388  447     True     10
# 4342          480        640     41  265  306  378  430     True     10
# 4663          480        640     12  295  307  401  431     True     10
# 4665          480        640     19  338  357  395  426     True     10
# 4707          240        320     16  111  127  171  213     True     10
# 5280         1200       1600     37  918  955  735  783     True     10
# ...           ...        ...    ...  ...  ...  ...  ...      ...    ...
# 21515         480        640    106  336  442   17  175     True     60
# 23030         480        640     36  271  307   64  112     True     60
# 23334         480        640     38  320  358  278  316     True     60
# 23429         480        640     49  214  263   77  142     True     60
# 23556         480        640     32   63   95  326  393     True     60
# 24360         480        640     63  386  449  214  295     True     60
# 25169         480        640     35  312  347  251  299     True     60
# 25355         480        640     53  163  216   72  144     True     60
# 25423         480        640     93   62  155   23  130     True     60
# 25662         480        640     31  474  505  346  393    False     60
# 25753         480        640    103   66  169  233  368    False     60
# 25820         480        640     65  191  256   38   95    False     60
# 26050         480        640     21  432  453  422  450    False     60
# 26084         480        640     55  235  290  334  427    False     60
# 26115         480        640     18  511  529  283  313    False     60
# 26589         480        640     95  205  300  246  354    False     60
# 26676         480        640    112    8  120  295  398    False     60
# 27284         480        640     56  111  167  348  424    False     60
# 27315         480        640     42  228  270  248  285    False     60
# 27353         480        640    119  200  319  299  414    False     60
# 27640         480        640     62   21   83  238  311    False     60
# 27994         480        640     39  308  347  412  458    False     60
# 28028         480        640     37  139  176  255  362    False     60
# 28043         480        640     60  171  231  376  422    False     60
# 28513         480        640     69  299  368  218  292    False     60
# 30364         480        640     85  395  480  176  243    False     60
# 31216         480        640     63   23   86  409  475    False     60
# 33391         480        640    136  453  589  267  409    False     60
# 33424         480        640     76  416  492  282  353    False     60
# 33437         480        640    104  120  224   41  263    False     60
#
# [22176 rows x 14 columns]

# %%
# datasetDF.loc[(datasetDF['x1'] > 0) & (datasetDF['x2'] < datasetDF['src_width']) & (datasetDF['y1'] > 0) & (datasetDF['y2'] < datasetDF['src_height']) & (datasetDF['x1'] < datasetDF['x2']) & (datasetDF['y1'] < datasetDF['y2'])]

datasetDF.loc[(datasetDF['x1'] == 0), 'x1'] = 1
datasetDF.loc[(datasetDF['y1'] == 0), 'y1'] = 1
datasetDF.loc[(datasetDF['x2'] >= datasetDF['src_width']), 'x2'] = datasetDF.loc[(datasetDF['x2'] >= datasetDF['src_width']), 'src_width'] - 1
datasetDF.loc[(datasetDF['y2'] >= datasetDF['src_height']), 'y2'] = datasetDF.loc[(datasetDF['y2'] >= datasetDF['src_height']), 'src_height'] - 1

# datasetDF.loc[(datasetDF['x1'] < datasetDF['x2']) & (datasetDF['y1'] < datasetDF['y2'])]

# %%
# datasetDF.loc[(datasetDF['x1'] > 0) == False, 'x1'] = 1

datasetDF.loc[(datasetDF['x2'] >= datasetDF['src_width'])]
# datasetDF.loc[(datasetDF['y1'] == 0)]
# Out:
# Empty DataFrame
# Columns: [char, height, origin_path, path, seg_areas, src_height, src_width, width, x1, x2, y1, y2, isTrain, label]
# Index: []

# %%
datasetDF
# Out:
#       char  height                                        origin_path  \
# 766      8      24  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 812      8      27  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 902      8      32  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 1455     8      37  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 1460     8      36  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 1463     8      34  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 1554     8      44  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 1648     8      42  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 1651     8      43  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 1653     8      41  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 1680     8      82  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 1986     8      44  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 1992     8      42  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 2033     8      54  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 2035     8      50  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 2051     8      32  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 2127     8      58  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 2447     8      33  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 2842     8      65  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 3131     8      50  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 3132     8      49  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 3267     8      22  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 3268     8      23  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 3269     8      24  kaist_dataset/English/Digital_Camera/(E.S)C-ou...
# 4337     8      59  kaist_dataset/English/Digital_Camera/(E.S)E-ni...
# 4342     8      52  kaist_dataset/English/Digital_Camera/(E.S)E-ni...
# 4663     8      30  kaist_dataset/English/Digital_Camera/(E.S)F-ot...
# 4665     8      31  kaist_dataset/English/Digital_Camera/(E.S)F-ot...
# 4707     8      42  kaist_dataset/English/Digital_Camera/(E.S)F-ot...
# 5280     8      48  kaist_dataset/Korean/Digital_Camera/A-shadow/2...
# ...    ...     ...                                                ...
# 21515    만     158  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 23030    만      48  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 23334    만      38  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 23429    만      65  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 23556    만      67  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 24360    만      81  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 25169    만      48  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 25355    만      72  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 25423    만     107  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 25662    만      47  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 25753    만     135  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 25820    만      57  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 26050    만      28  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 26084    만      93  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 26115    만      30  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 26589    만     108  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 26676    만     103  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 27284    만      76  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 27315    만      37  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 27353    만     115  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 27640    만      73  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 27994    만      46  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 28028    만     107  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 28043    만      46  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 28513    만      74  kaist_dataset/Mixed/Digital_Camera/(C.S)C-outd...
# 30364    만      67  kaist_dataset/Mixed/Digital_Camera/(C.S)D-indo...
# 31216    만      66  kaist_dataset/Mixed/Digital_Camera/(C.S)D-indo...
# 33391    만     142  kaist_dataset/Mixed/Mobile_Phone/(C.M)C-bookCo...
# 33424    만      71  kaist_dataset/Mixed/Mobile_Phone/(C.M)C-bookCo...
# 33437    만     222  kaist_dataset/Mixed/Mobile_Phone/(C.M)C-bookCo...
#
#                                                     path  seg_areas  \
# 766                            char_data/8/042.JPG_2.jpg        456
# 812                            char_data/8/056.JPG_2.jpg        432
# 902                            char_data/8/077.JPG_2.jpg        544
# 1455                      char_data/8/DSC02364.JPG_6.jpg        518
# 1460                      char_data/8/DSC02364.JPG_7.jpg        756
# 1463                      char_data/8/DSC02364.JPG_8.jpg        544
# 1554                      char_data/8/DSC02415.JPG_2.jpg       1144
# 1648                      char_data/8/DSC02450.JPG_6.jpg       1386
# 1651                      char_data/8/DSC02450.JPG_7.jpg       1462
# 1653                      char_data/8/DSC02450.JPG_8.jpg       1189
# 1680                      char_data/8/DSC02491.JPG_2.jpg       3772
# 1986                      char_data/8/DSC03053.JPG_4.jpg       1188
# 1992                      char_data/8/DSC03053.JPG_5.jpg       1176
# 2033                      char_data/8/DSC03161.JPG_4.jpg       1674
# 2035                      char_data/8/DSC03161.JPG_5.jpg       1650
# 2051                      char_data/8/DSC03162.JPG_2.jpg        448
# 2127                      char_data/8/DSC03201.JPG_2.jpg       2146
# 2447                      char_data/8/DSC03436.JPG_2.jpg        825
# 2842                      char_data/8/DSC04163.JPG_2.jpg       2535
# 3131                      char_data/8/P1010086.JPG_6.jpg       1550
# 3132                      char_data/8/P1010086.JPG_7.jpg       1323
# 3267           char_data/8/크기변환_P1010076.JPG_6.jpg        242
# 3268           char_data/8/크기변환_P1010076.JPG_7.jpg        207
# 3269           char_data/8/크기변환_P1010076.JPG_8.jpg        360
# 4337                      char_data/8/DSC02610.JPG_4.jpg       2006
# 4342                      char_data/8/DSC02610.JPG_5.jpg       2132
# 4663                      char_data/8/DSC02923.JPG_4.jpg        360
# 4665                      char_data/8/DSC02923.JPG_5.jpg        589
# 4707                             char_data/8/m.jpg_2.jpg        672
# 5280   char_data/8/2007-12-09-day-exterior-025.jpg_4.jpg       1776
# ...                                                  ...        ...
# 21515                     char_data/만/DSC02359.JPG_2.jpg      16748
# 23030                     char_data/만/DSC02912.JPG_2.jpg       1728
# 23334                     char_data/만/P1010013.JPG_2.jpg       1444
# 23429                     char_data/만/DSC02964.JPG_2.jpg       3185
# 23556                     char_data/만/DSC02989.JPG_2.jpg       2144
# 24360                     char_data/만/DSC03273.JPG_2.jpg       5103
# 25169                     char_data/만/DSC03556.JPG_2.jpg       1680
# 25355                     char_data/만/DSC03586.JPG_2.jpg       3816
# 25423                     char_data/만/DSC03616.JPG_2.jpg       9951
# 25662                     char_data/만/DSC03642.JPG_2.jpg       1457
# 25753                     char_data/만/DSC03655.JPG_2.jpg      13905
# 25820                     char_data/만/DSC03660.JPG_2.jpg       3705
# 26050                     char_data/만/DSC03674.JPG_2.jpg        588
# 26084                     char_data/만/DSC03676.JPG_2.jpg       5115
# 26115                     char_data/만/DSC03677.JPG_2.jpg        540
# 26589                     char_data/만/DSC03734.JPG_2.jpg      10260
# 26676                     char_data/만/DSC03743.JPG_2.jpg      11536
# 27284                     char_data/만/DSC04017.JPG_2.jpg       4256
# 27315                     char_data/만/DSC04029.JPG_2.jpg       1554
# 27353                     char_data/만/DSC04032.JPG_2.jpg      13685
# 27640                     char_data/만/DSC04071.JPG_2.jpg       4526
# 27994                     char_data/만/DSC04125.JPG_2.jpg       1794
# 28028                     char_data/만/DSC04135.JPG_4.jpg       3959
# 28043                     char_data/만/DSC04135.JPG_5.jpg       2760
# 28513                     char_data/만/DSC04357.JPG_2.jpg       5106
# 30364                     char_data/만/DSC02782.JPG_2.jpg       5695
# 31216                     char_data/만/DSC03998.JPG_2.jpg       4158
# 33391                   char_data/만/P090903022.jpg_2.jpg      19312
# 33424                   char_data/만/P090903024.jpg_2.jpg       5396
# 33437                   char_data/만/P090903063.jpg_2.jpg      23088
#
#        src_height  src_width  width   x1   x2   y1   y2  isTrain  label
# 766           480        640     19  485  504  321  345     True     10
# 812           480        640     16  513  529  249  276     True     10
# 902           480        640     17  276  293  248  280     True     10
# 1455          480        640     14  325  339  350  387     True     10
# 1460          480        640     21  486  507  353  389     True     10
# 1463          480        640     16  549  565  353  387     True     10
# 1554          480        640     26  393  419  250  294     True     10
# 1648          480        640     33  109  142  222  264     True     10
# 1651          480        640     34  265  299  222  265     True     10
# 1653          480        640     29  353  382  221  262     True     10
# 1680          480        640     46  238  284  315  397     True     10
# 1986          480        640     27  335  362  128  172     True     10
# 1992          480        640     28  513  541  128  170     True     10
# 2033          480        640     31  138  169  221  275     True     10
# 2035          480        640     33  200  233  223  273     True     10
# 2051          480        640     14  425  439  149  181     True     10
# 2127          480        640     37  364  401   11   69     True     10
# 2447          480        640     25  221  246  126  159     True     10
# 2842          480        640     39  194  233  316  381     True     10
# 3131          480        640     31  423  454   96  146     True     10
# 3132          480        640     27  453  480   96  145     True     10
# 3267          480        640     11  581  592  181  203     True     10
# 3268          480        640      9  595  604  182  205     True     10
# 3269          480        640     15  611  626  179  203     True     10
# 4337          480        640     34   50   84  388  447     True     10
# 4342          480        640     41  265  306  378  430     True     10
# 4663          480        640     12  295  307  401  431     True     10
# 4665          480        640     19  338  357  395  426     True     10
# 4707          240        320     16  111  127  171  213     True     10
# 5280         1200       1600     37  918  955  735  783     True     10
# ...           ...        ...    ...  ...  ...  ...  ...      ...    ...
# 21515         480        640    106  336  442   17  175     True     60
# 23030         480        640     36  271  307   64  112     True     60
# 23334         480        640     38  320  358  278  316     True     60
# 23429         480        640     49  214  263   77  142     True     60
# 23556         480        640     32   63   95  326  393     True     60
# 24360         480        640     63  386  449  214  295     True     60
# 25169         480        640     35  312  347  251  299     True     60
# 25355         480        640     53  163  216   72  144     True     60
# 25423         480        640     93   62  155   23  130     True     60
# 25662         480        640     31  474  505  346  393    False     60
# 25753         480        640    103   66  169  233  368    False     60
# 25820         480        640     65  191  256   38   95    False     60
# 26050         480        640     21  432  453  422  450    False     60
# 26084         480        640     55  235  290  334  427    False     60
# 26115         480        640     18  511  529  283  313    False     60
# 26589         480        640     95  205  300  246  354    False     60
# 26676         480        640    112    8  120  295  398    False     60
# 27284         480        640     56  111  167  348  424    False     60
# 27315         480        640     42  228  270  248  285    False     60
# 27353         480        640    119  200  319  299  414    False     60
# 27640         480        640     62   21   83  238  311    False     60
# 27994         480        640     39  308  347  412  458    False     60
# 28028         480        640     37  139  176  255  362    False     60
# 28043         480        640     60  171  231  376  422    False     60
# 28513         480        640     69  299  368  218  292    False     60
# 30364         480        640     85  395  480  176  243    False     60
# 31216         480        640     63   23   86  409  475    False     60
# 33391         480        640    136  453  589  267  409    False     60
# 33424         480        640     76  416  492  282  353    False     60
# 33437         480        640    104  120  224   41  263    False     60
#
# [22244 rows x 14 columns]

# %%
np.log(1)
# Out:
# 0.0

# %% [markdown]
# # Kaist dataset preprocessing for Faster-RCNN
# 1.
